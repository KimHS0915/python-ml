# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from bayes_opt import BayesianOptimization
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from lightgbm import LGBMClassifier

# %%
def get_apps_dataset():
    app_train = pd.read_csv('../data/home-credit-default-risk/application_train.csv')
    app_test = pd.read_csv('../data/home-credit-default-risk/application_test.csv')
    apps = pd.concat([app_train, app_test])
    prev = pd.read_csv('../data/home-credit-default-risk/previous_application.csv')
    
    return apps, prev


def get_apps_processed(apps):
    apps['APPS_EXT_SOURCE_MEAN'] = apps[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']].mean(axis=1)
    apps['APPS_EXT_SOURCE_STD'] = apps[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']].std(axis=1)
    apps['APPS_EXT_SOURCE_STD'] = apps['APPS_EXT_SOURCE_STD'].fillna(apps['APPS_EXT_SOURCE_STD'].mean())
    
    apps['APPS_ANNUITY_CREDIT_RATIO'] = apps['AMT_ANNUITY'] / apps['AMT_CREDIT']
    apps['APPS_GOODS_CREDIT_RATIO'] = apps['AMT_GOODS_PRICE'] / apps['AMT_CREDIT']
    apps['APPS_CREDIT_GOODS_DIFF'] = apps['AMT_CREDIT'] - apps['AMT_GOODS_PRICE']
    
    apps['APPS_ANNUITY_INCOME_RATIO'] = apps['AMT_ANNUITY'] / apps['AMT_INCOME_TOTAL']
    apps['APPS_CREDIT_INCOME_RATIO'] = apps['AMT_CREDIT'] / apps['AMT_INCOME_TOTAL']
    apps['APPS_GOODS_INCOME_RATIO'] = apps['AMT_GOODS_PRICE'] / apps['AMT_INCOME_TOTAL']
    apps['APPS_CNT_FAM_INCOME_RATIO'] = apps['AMT_INCOME_TOTAL'] / apps['CNT_FAM_MEMBERS']
    
    apps['APPS_EMPLOYED_BIRTH_RATIO'] = apps['DAYS_EMPLOYED'] / apps['DAYS_BIRTH']
    apps['APPS_INCOME_EMPLOYED_RATIO'] = apps['AMT_INCOME_TOTAL'] / apps['DAYS_EMPLOYED']
    apps['APPS_INCOME_BIRTH_RATIO'] = apps['AMT_INCOME_TOTAL'] / apps['DAYS_BIRTH']
    apps['APPS_CAR_BIRTH_RATIO'] = apps['OWN_CAR_AGE'] / apps['DAYS_BIRTH']
    apps['APPS_CAR_EMPLOYED_RATIO'] = apps['OWN_CAR_AGE'] / apps['DAYS_EMPLOYED']
    
    return apps

# %%
def get_prev_processed(prev):
    
    prev['PREV_CREDIT_DIFF'] = prev['AMT_APPLICATION'] - prev['AMT_CREDIT']
    prev['PREV_GOODS_DIFF'] = prev['AMT_APPLICATION'] - prev['AMT_GOODS_PRICE']
    prev['PREV_CREDIT_APPL_RATIO'] = prev['AMT_CREDIT'] / prev['AMT_APPLICATION']
    prev['PREV_ANNUITY_APPL_RATIO'] = prev['AMT_ANNUITY'] / prev['AMT_APPLICATION']
    prev['PREV_GOODS_APPL_RATIO'] = prev['AMT_GOODS_PRICE'] / prev['AMT_APPLICATION']
    
    prev['DAYS_FIRST_DRAWING'].replace(365243, np.nan, inplace=True)
    prev['DAYS_FIRST_DUE'].replace(365243, np.nan, inplace=True)
    prev['DAYS_LAST_DUE_1ST_VERSION'].replace(365243, np.nan, inplace=True)
    prev['DAYS_LAST_DUE'].replace(365243, np.nan, inplace=True)
    prev['DAYS_TERMINATION'].replace(365243, np.nan, inplace=True)

    prev['PREV_DAYS_LAST_DUE_DIFF'] = prev['DAYS_LAST_DUE_1ST_VERSION'] - prev['DAYS_LAST_DUE']
    
    all_pay = prev['AMT_ANNUITY'] * prev['CNT_PAYMENT']
    prev['PREV_INTERESTS_RATE'] = (all_pay / prev['AMT_CREDIT'] - 1) / prev['CNT_PAYMENT']
    
    return prev


def get_prev_amt_agg(prev):    

    agg_dict = {
         # 기존 컬럼. 
        'SK_ID_CURR':['count'],
        'AMT_CREDIT':['mean', 'max', 'sum'],
        'AMT_ANNUITY':['mean', 'max', 'sum'], 
        'AMT_APPLICATION':['mean', 'max', 'sum'],
        'AMT_DOWN_PAYMENT':['mean', 'max', 'sum'],
        'AMT_GOODS_PRICE':['mean', 'max', 'sum'],
        'RATE_DOWN_PAYMENT': ['min', 'max', 'mean'],
        'DAYS_DECISION': ['min', 'max', 'mean'],
        'CNT_PAYMENT': ['mean', 'sum'],
        # 가공 컬럼
        'PREV_CREDIT_DIFF':['mean', 'max', 'sum'], 
        'PREV_CREDIT_APPL_RATIO':['mean', 'max'],
        'PREV_GOODS_DIFF':['mean', 'max', 'sum'],
        'PREV_GOODS_APPL_RATIO':['mean', 'max'],
        'PREV_DAYS_LAST_DUE_DIFF':['mean', 'max', 'sum'],
        'PREV_INTERESTS_RATE':['mean', 'max']
    }
    
    prev_group = prev.groupby('SK_ID_CURR')
    prev_amt_agg = prev_group.agg(agg_dict)
    prev_amt_agg.columns = ['PREV_' + ('_').join(column).upper() for column in prev_amt_agg.columns.ravel()]
    prev_amt_agg = prev_amt_agg.reset_index()
    
    return prev_amt_agg


def get_prev_refused_appr_agg(prev):

    prev_refused_appr_group = prev[prev['NAME_CONTRACT_STATUS'].isin(['Approved', 'Refused'])].groupby(['SK_ID_CURR', 'NAME_CONTRACT_STATUS'])
    prev_refused_appr_agg = prev_refused_appr_group['SK_ID_CURR'].count().unstack()
    prev_refused_appr_agg = prev_refused_appr_agg.fillna(0)
    prev_refused_appr_agg.columns = ['PREV_APPROVED_COUNT', 'PREV_REFUSED_COUNT']
    prev_refused_appr_agg = prev_refused_appr_agg.reset_index()
    
    return prev_refused_appr_agg


def get_prev_agg(prev):
    
    prev = get_prev_processed(prev)
    prev_amt_agg = get_prev_amt_agg(prev)
    prev_refused_appr_agg = get_prev_refused_appr_agg(prev)
    
    prev_agg = prev_amt_agg.merge(prev_refused_appr_agg, on='SK_ID_CURR', how='left')
    prev_agg['PREV_REFUSED_RATIO'] = prev_agg['PREV_REFUSED_COUNT'] / prev_agg['PREV_SK_ID_CURR_COUNT']
    prev_agg['PREV_APPROVED_RATIO'] = prev_agg['PREV_APPROVED_COUNT'] / prev_agg['PREV_SK_ID_CURR_COUNT']
    prev_agg = prev_agg.drop(['PREV_REFUSED_COUNT', 'PREV_APPROVED_COUNT'], axis=1)
    
    return prev_agg


def get_apps_all_with_prev_agg(apps, prev):

    apps_all = get_apps_processed(apps)
    prev_agg = get_prev_agg(prev)
    print('prev_agg shape:', prev_agg.shape)
    print('apps_all before merge shape:', apps_all.shape)
    apps_all = apps_all.merge(prev_agg, on='SK_ID_CURR', how='left')
    print('apps_all after merge with prev_agg shape:', apps_all.shape)
    
    return apps_all


def get_apps_all_encoded(apps_all):
    
    object_columns = apps_all.dtypes[apps_all.dtypes == 'object'].index.tolist()
    for column in object_columns:
        apps_all[column] = pd.factorize(apps_all[column])[0]
    
    return apps_all


def get_apps_all_train_test(apps_all):

    apps_all_train = apps_all[~apps_all['TARGET'].isnull()]
    apps_all_test = apps_all[apps_all['TARGET'].isnull()]
    apps_all_test = apps_all_test.drop('TARGET', axis=1)
    
    return apps_all_train, apps_all_test


def train_apps_all(apps_all_train):
    
    ftr_app = apps_all_train.drop(['SK_ID_CURR', 'TARGET'], axis=1)
    target_app = apps_all_train['TARGET']

    train_x, valid_x, train_y, valid_y = train_test_split(ftr_app, target_app, test_size=0.3, random_state=0)
    print(f'train shape: {train_x.shape}, valid shape: {valid_x.shape}')
    
    clf = LGBMClassifier(n_jobs=-1, n_estimators=1000, learning_rate=0.02, num_leaves=32, 
                         subsample=0.8, max_depth=12, silent=-1, verbose=-1)
    clf.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], 
            eval_metric='auc', verbose=100, early_stopping_rounds=100)
    
    return clf

# %%
apps, prev = get_apps_dataset()
apps_all = get_apps_all_with_prev_agg(apps, prev)
apps_all = get_apps_all_encoded(apps_all)
apps_all_train, apps_all_test = get_apps_all_train_test(apps_all)
print(f'apps_all_train.shape: {apps_all_train.shape}, apps_all_test.shape: {apps_all_test.shape}')
# Out:
# prev_agg shape: (338857, 42)
# apps_all before merge shape: (356255, 136)
# apps_all after merge with prev_agg shape: (356255, 177)
# apps_all_train.shape: (307511, 177), apps_all_test.shape: (48744, 176)

# %%
ftr_app = apps_all_train.drop(['SK_ID_CURR', 'TARGET'], axis=1)
target_app = apps_all_train['TARGET']
train_x, valid_x, train_y, valid_y = train_test_split(ftr_app, target_app, test_size=0.3, random_state=0)

# %%
bayesian_params = {
    'max_depth': (6, 16),
    'num_leaves': (24, 64),
    'min_child_samples': (10, 200),
    'min_child_weight': (1, 50),
    'subsample': (0.5, 1),
    'colsample_bytree': (0.5, 1),
    'max_bin': (10, 500),
    'reg_lambda': (0.001, 10),
    'reg_alpha': (0.01, 50),
}

# %%
def lgb_roc_eval(max_depth, num_leaves, min_child_samples, min_child_weight, subsample,
                colsample_bytree, max_bin, reg_lambda, reg_alpha):
    
    params = {
        "num_iterations": 500, 
        "learning_rate": 0.02,
        'max_depth': int(round(max_depth)),
        'num_leaves': int(round(num_leaves)),
        'min_child_samples': int(round(min_child_samples)),
        'min_child_weight': int(round(min_child_weight)),
        'subsample': max(min(subsample, 1), 0),
        'colsample_bytree': max(min(colsample_bytree, 1), 0),
        'max_bin': max(int(round(max_bin)), 10),
        'reg_lambda': max(reg_lambda, 0),
        'reg_alpha': max(reg_alpha, 0),
    }
    print(params)
    
    lgb_model = LGBMClassifier(**params)
    lgb_model.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], 
                  eval_metric='auc', verbose=100, early_stopping_rounds= 100)
    valid_proba = lgb_model.predict_proba(valid_x)[:, 1]
    roc_auc = roc_auc_score(valid_y, valid_proba)
    
    return roc_auc

# %%
lgbBO = BayesianOptimization(f=lgb_roc_eval, pbounds=bayesian_params, random_state=0)
lgbBO.maximize(init_points=5, n_iter=25)
# Out:
# |   iter    |  target   | colsam... |  max_bin  | max_depth | min_ch... | min_ch... | num_le... | reg_alpha | reg_la... | subsample |
# -------------------------------------------------------------------------------------------------------------------------------------
# {'num_iterations': 500, 'learning_rate': 0.02, 'max_depth': 12, 'num_leaves': 50, 'min_child_samples': 114, 'min_child_weight': 22, 'subsample': 0.9818313802505146, 'colsample_bytree': 0.7744067519636624, 'max_bin': 360, 'reg_lambda': 8.917838234820016, 'reg_alpha': 21.884984691022}
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.769542	training's binary_logloss: 0.246863	valid_1's auc: 0.755399	valid_1's binary_logloss: 0.247029
# [200]	training's auc: 0.786767	training's binary_logloss: 0.239327	valid_1's auc: 0.766757	valid_1's binary_logloss: 0.24212
# [300]	training's auc: 0.798311	training's binary_logloss: 0.234892	valid_1's auc: 0.772621	valid_1's binary_logloss: 0.240097
# [400]	training's auc: 0.807514	training's binary_logloss: 0.231456	valid_1's auc: 0.775881	valid_1's binary_logloss: 0.238994
# [500]	training's auc: 0.815523	training's binary_logloss: 0.228482	valid_1's auc: 0.777941	valid_1's binary_logloss: 0.238296
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.815523	training's binary_logloss: 0.228482	valid_1's auc: 0.777941	valid_1's binary_logloss: 0.238296
# |  1        |  0.7779   |  0.7744   |  360.4    |  12.03    |  113.5    |  21.76    |  49.84    |  21.88    |  8.918    |  0.9818   |
# {'num_iterations': 500, 'learning_rate': 0.02, 'max_depth': 11, 'num_leaves': 27, 'min_child_samples': 118, 'min_child_weight': 46, 'subsample': 0.916309922773969, 'colsample_bytree': 0.6917207594128889, 'max_bin': 398, 'reg_lambda': 0.20316375600581688, 'reg_alpha': 4.36559369208002}
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.762594	training's binary_logloss: 0.248243	valid_1's auc: 0.753428	valid_1's binary_logloss: 0.247239
# [200]	training's auc: 0.779848	training's binary_logloss: 0.241237	valid_1's auc: 0.766186	valid_1's binary_logloss: 0.242192
# [300]	training's auc: 0.790395	training's binary_logloss: 0.237295	valid_1's auc: 0.772245	valid_1's binary_logloss: 0.240094
# [400]	training's auc: 0.798507	training's binary_logloss: 0.234347	valid_1's auc: 0.775431	valid_1's binary_logloss: 0.239029
# [500]	training's auc: 0.805574	training's binary_logloss: 0.231877	valid_1's auc: 0.777071	valid_1's binary_logloss: 0.238472
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.805574	training's binary_logloss: 0.231877	valid_1's auc: 0.777071	valid_1's binary_logloss: 0.238472
# |  2        |  0.7771   |  0.6917   |  397.9    |  11.29    |  117.9    |  46.35    |  26.84    |  4.366    |  0.2032   |  0.9163   |
# {'num_iterations': 500, 'learning_rate': 0.02, 'max_depth': 16, 'num_leaves': 55, 'min_child_samples': 162, 'min_child_weight': 24, 'subsample': 0.5716766437045232, 'colsample_bytree': 0.8890783754749252, 'max_bin': 436, 'reg_lambda': 6.3995702922539115, 'reg_alpha': 5.922538549187972}
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.775982	training's binary_logloss: 0.244609	valid_1's auc: 0.757124	valid_1's binary_logloss: 0.246116
# [200]	training's auc: 0.796829	training's binary_logloss: 0.235777	valid_1's auc: 0.76892	valid_1's binary_logloss: 0.24123
# [300]	training's auc: 0.811918	training's binary_logloss: 0.229991	valid_1's auc: 0.774843	valid_1's binary_logloss: 0.239231
# [400]	training's auc: 0.824596	training's binary_logloss: 0.225262	valid_1's auc: 0.77723	valid_1's binary_logloss: 0.238399
# [500]	training's auc: 0.835414	training's binary_logloss: 0.221104	valid_1's auc: 0.778457	valid_1's binary_logloss: 0.237955
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.835414	training's binary_logloss: 0.221104	valid_1's auc: 0.778457	valid_1's binary_logloss: 0.237955
# |  3        |  0.7785   |  0.8891   |  436.3    |  15.79    |  161.8    |  23.61    |  55.22    |  5.923    |  6.4      |  0.5717   |
# {'num_iterations': 500, 'learning_rate': 0.02, 'max_depth': 10, 'num_leaves': 42, 'min_child_samples': 60, 'min_child_weight': 39, 'subsample': 0.8088177485379385, 'colsample_bytree': 0.972334458524792, 'max_bin': 266, 'reg_lambda': 0.18887921456311507, 'reg_alpha': 28.426013103943742}
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.765693	training's binary_logloss: 0.247819	valid_1's auc: 0.753597	valid_1's binary_logloss: 0.247444
# [200]	training's auc: 0.782699	training's binary_logloss: 0.240633	valid_1's auc: 0.765836	valid_1's binary_logloss: 0.242466
# [300]	training's auc: 0.792845	training's binary_logloss: 0.236708	valid_1's auc: 0.771413	valid_1's binary_logloss: 0.240492
# [400]	training's auc: 0.800782	training's binary_logloss: 0.233728	valid_1's auc: 0.774718	valid_1's binary_logloss: 0.239366
# [500]	training's auc: 0.807664	training's binary_logloss: 0.231224	valid_1's auc: 0.776591	valid_1's binary_logloss: 0.238727
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.807664	training's binary_logloss: 0.231224	valid_1's auc: 0.776591	valid_1's binary_logloss: 0.238727
# |  4        |  0.7766   |  0.9723   |  265.7    |  10.15    |  60.27    |  38.94    |  42.25    |  28.43    |  0.1889   |  0.8088   |
# {'num_iterations': 500, 'learning_rate': 0.02, 'max_depth': 15, 'num_leaves': 41, 'min_child_samples': 140, 'min_child_weight': 19, 'subsample': 0.8333833577228338, 'colsample_bytree': 0.8060478613612108, 'max_bin': 312, 'reg_lambda': 0.6031944908210691, 'reg_alpha': 34.88458348440397}
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.765315	training's binary_logloss: 0.248187	valid_1's auc: 0.753511	valid_1's binary_logloss: 0.247722
# [200]	training's auc: 0.781093	training's binary_logloss: 0.241203	valid_1's auc: 0.765072	valid_1's binary_logloss: 0.242753
# [300]	training's auc: 0.790854	training's binary_logloss: 0.237442	valid_1's auc: 0.770936	valid_1's binary_logloss: 0.240697
# [400]	training's auc: 0.79837	training's binary_logloss: 0.234642	valid_1's auc: 0.774286	valid_1's binary_logloss: 0.239561
# [500]	training's auc: 0.804804	training's binary_logloss: 0.232328	valid_1's auc: 0.776161	valid_1's binary_logloss: 0.238929
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.804804	training's binary_logloss: 0.232328	valid_1's auc: 0.776161	valid_1's binary_logloss: 0.238929
# |  5        |  0.7762   |  0.806    |  312.3    |  15.44    |  139.5    |  18.62    |  41.48    |  34.88    |  0.6032   |  0.8334   |
# {'num_iterations': 500, 'learning_rate': 0.02, 'max_depth': 13, 'num_leaves': 58, 'min_child_samples': 169, 'min_child_weight': 27, 'subsample': 0.6129607288812317, 'colsample_bytree': 0.640481830861817, 'max_bin': 435, 'reg_lambda': 9.196441703351635, 'reg_alpha': 5.7675960060342195}
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.777573	training's binary_logloss: 0.244723	valid_1's auc: 0.758846	valid_1's binary_logloss: 0.246121
# [200]	training's auc: 0.797174	training's binary_logloss: 0.235809	valid_1's auc: 0.769419	valid_1's binary_logloss: 0.241148
# [300]	training's auc: 0.811755	training's binary_logloss: 0.230149	valid_1's auc: 0.774698	valid_1's binary_logloss: 0.239283
# [400]	training's auc: 0.824116	training's binary_logloss: 0.225475	valid_1's auc: 0.777405	valid_1's binary_logloss: 0.238358
# [500]	training's auc: 0.83509	training's binary_logloss: 0.22134	valid_1's auc: 0.778679	valid_1's binary_logloss: 0.237902
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.83509	training's binary_logloss: 0.22134	valid_1's auc: 0.778679	valid_1's binary_logloss: 0.237902
# |  6        |  0.7787   |  0.6405   |  435.0    |  13.5     |  169.3    |  26.92    |  57.69    |  5.768    |  9.196    |  0.613    |
# {'num_iterations': 500, 'learning_rate': 0.02, 'max_depth': 12, 'num_leaves': 53, 'min_child_samples': 199, 'min_child_weight': 14, 'subsample': 0.821334265834883, 'colsample_bytree': 0.7458994896937481, 'max_bin': 435, 'reg_lambda': 8.539189077900696, 'reg_alpha': 24.607737391152277}
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.770824	training's binary_logloss: 0.246817	valid_1's auc: 0.755844	valid_1's binary_logloss: 0.247075
# [200]	training's auc: 0.787721	training's binary_logloss: 0.239152	valid_1's auc: 0.766709	valid_1's binary_logloss: 0.242149
# [300]	training's auc: 0.799065	training's binary_logloss: 0.234728	valid_1's auc: 0.772531	valid_1's binary_logloss: 0.240108
# [400]	training's auc: 0.808209	training's binary_logloss: 0.231292	valid_1's auc: 0.775694	valid_1's binary_logloss: 0.239041
# [500]	training's auc: 0.816421	training's binary_logloss: 0.228276	valid_1's auc: 0.777765	valid_1's binary_logloss: 0.238351
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.816421	training's binary_logloss: 0.228276	valid_1's auc: 0.777765	valid_1's binary_logloss: 0.238351
# |  7        |  0.7778   |  0.7459   |  434.9    |  11.55    |  198.6    |  13.76    |  53.11    |  24.61    |  8.539    |  0.8213   |
# {'num_iterations': 500, 'learning_rate': 0.02, 'max_depth': 8, 'num_leaves': 56, 'min_child_samples': 182, 'min_child_weight': 49, 'subsample': 0.8259963788588284, 'colsample_bytree': 0.6784692502274292, 'max_bin': 456, 'reg_lambda': 2.764765966445203, 'reg_alpha': 11.312397944233792}
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.775464	training's binary_logloss: 0.245526	valid_1's auc: 0.757745	valid_1's binary_logloss: 0.246397
# [200]	training's auc: 0.792797	training's binary_logloss: 0.237488	valid_1's auc: 0.76804	valid_1's binary_logloss: 0.241596
# [300]	training's auc: 0.804402	training's binary_logloss: 0.23286	valid_1's auc: 0.773076	valid_1's binary_logloss: 0.239779
# [400]	training's auc: 0.81391	training's binary_logloss: 0.229229	valid_1's auc: 0.775866	valid_1's binary_logloss: 0.238835
# [500]	training's auc: 0.822368	training's binary_logloss: 0.226079	valid_1's auc: 0.777493	valid_1's binary_logloss: 0.238312
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.822368	training's binary_logloss: 0.226079	valid_1's auc: 0.777493	valid_1's binary_logloss: 0.238312
# |  8        |  0.7775   |  0.6785   |  455.7    |  8.435    |  182.0    |  49.45    |  55.56    |  11.31    |  2.765    |  0.826    |
# {'num_iterations': 500, 'learning_rate': 0.02, 'max_depth': 9, 'num_leaves': 63, 'min_child_samples': 161, 'min_child_weight': 31, 'subsample': 0.6222340399875712, 'colsample_bytree': 0.6718633505505451, 'max_bin': 410, 'reg_lambda': 8.332020869230849, 'reg_alpha': 9.031435769251694}
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.777979	training's binary_logloss: 0.244705	valid_1's auc: 0.758472	valid_1's binary_logloss: 0.246201
# [200]	training's auc: 0.796468	training's binary_logloss: 0.236127	valid_1's auc: 0.768872	valid_1's binary_logloss: 0.241371
# [300]	training's auc: 0.809844	training's binary_logloss: 0.230848	valid_1's auc: 0.773845	valid_1's binary_logloss: 0.23956
# [400]	training's auc: 0.820863	training's binary_logloss: 0.22665	valid_1's auc: 0.776615	valid_1's binary_logloss: 0.23864
# [500]	training's auc: 0.830707	training's binary_logloss: 0.222935	valid_1's auc: 0.778201	valid_1's binary_logloss: 0.238099
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.830707	training's binary_logloss: 0.222935	valid_1's auc: 0.778201	valid_1's binary_logloss: 0.238099
# |  9        |  0.7782   |  0.6719   |  409.6    |  9.469    |  160.8    |  30.56    |  63.2     |  9.031    |  8.332    |  0.6222   |
# {'num_iterations': 500, 'learning_rate': 0.02, 'max_depth': 14, 'num_leaves': 29, 'min_child_samples': 176, 'min_child_weight': 18, 'subsample': 0.9498668656246243, 'colsample_bytree': 0.7672686131215163, 'max_bin': 416, 'reg_lambda': 6.968999613934444, 'reg_alpha': 8.072671905016172}
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.763261	training's binary_logloss: 0.248309	valid_1's auc: 0.753616	valid_1's binary_logloss: 0.247324
# [200]	training's auc: 0.78022	training's binary_logloss: 0.241265	valid_1's auc: 0.765992	valid_1's binary_logloss: 0.242242
# [300]	training's auc: 0.79063	training's binary_logloss: 0.237341	valid_1's auc: 0.772147	valid_1's binary_logloss: 0.24011
# [400]	training's auc: 0.798674	training's binary_logloss: 0.2344	valid_1's auc: 0.775283	valid_1's binary_logloss: 0.239042
# [500]	training's auc: 0.805618	training's binary_logloss: 0.23192	valid_1's auc: 0.777154	valid_1's binary_logloss: 0.238429
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.805618	training's binary_logloss: 0.23192	valid_1's auc: 0.777154	valid_1's binary_logloss: 0.238429
# |  10       |  0.7772   |  0.7673   |  416.5    |  13.98    |  176.4    |  17.77    |  28.68    |  8.073    |  6.969    |  0.9499   |
# {'num_iterations': 500, 'learning_rate': 0.02, 'max_depth': 14, 'num_leaves': 64, 'min_child_samples': 163, 'min_child_weight': 22, 'subsample': 0.7226112226721547, 'colsample_bytree': 0.6064052328429193, 'max_bin': 413, 'reg_lambda': 8.472024590941542, 'reg_alpha': 14.185279785311755}
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.776639	training's binary_logloss: 0.245355	valid_1's auc: 0.758303	valid_1's binary_logloss: 0.246538
# [200]	training's auc: 0.794559	training's binary_logloss: 0.236878	valid_1's auc: 0.768359	valid_1's binary_logloss: 0.241614
# [300]	training's auc: 0.807923	training's binary_logloss: 0.231629	valid_1's auc: 0.773677	valid_1's binary_logloss: 0.239708
# [400]	training's auc: 0.81941	training's binary_logloss: 0.227291	valid_1's auc: 0.77639	valid_1's binary_logloss: 0.238761
# [500]	training's auc: 0.829796	training's binary_logloss: 0.223419	valid_1's auc: 0.77813	valid_1's binary_logloss: 0.238167
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.829796	training's binary_logloss: 0.223419	valid_1's auc: 0.77813	valid_1's binary_logloss: 0.238167
# |  11       |  0.7781   |  0.6064   |  413.4    |  13.83    |  163.5    |  22.24    |  63.87    |  14.19    |  8.472    |  0.7226   |
# {'num_iterations': 500, 'learning_rate': 0.02, 'max_depth': 8, 'num_leaves': 63, 'min_child_samples': 166, 'min_child_weight': 10, 'subsample': 0.8868793756279975, 'colsample_bytree': 0.9715993400563504, 'max_bin': 468, 'reg_lambda': 7.260412080797022, 'reg_alpha': 10.453510048238675}
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.776408	training's binary_logloss: 0.244712	valid_1's auc: 0.756919	valid_1's binary_logloss: 0.246284
# [200]	training's auc: 0.796177	training's binary_logloss: 0.236173	valid_1's auc: 0.768398	valid_1's binary_logloss: 0.241457
# [300]	training's auc: 0.809194	training's binary_logloss: 0.231007	valid_1's auc: 0.773636	valid_1's binary_logloss: 0.239613
# [400]	training's auc: 0.820001	training's binary_logloss: 0.226927	valid_1's auc: 0.775979	valid_1's binary_logloss: 0.238797
# [500]	training's auc: 0.829293	training's binary_logloss: 0.223349	valid_1's auc: 0.77759	valid_1's binary_logloss: 0.238244
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.829293	training's binary_logloss: 0.223349	valid_1's auc: 0.77759	valid_1's binary_logloss: 0.238244
# |  12       |  0.7776   |  0.9716   |  467.8    |  8.134    |  165.7    |  10.05    |  62.97    |  10.45    |  7.26     |  0.8869   |
# {'num_iterations': 500, 'learning_rate': 0.02, 'max_depth': 13, 'num_leaves': 44, 'min_child_samples': 116, 'min_child_weight': 27, 'subsample': 0.5242793368963636, 'colsample_bytree': 0.7515227016933802, 'max_bin': 358, 'reg_lambda': 9.179902256499673, 'reg_alpha': 28.27854101642585}
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.766494	training's binary_logloss: 0.247811	valid_1's auc: 0.753836	valid_1's binary_logloss: 0.247501
# [200]	training's auc: 0.782986	training's binary_logloss: 0.240664	valid_1's auc: 0.765628	valid_1's binary_logloss: 0.242552
# [300]	training's auc: 0.793386	training's binary_logloss: 0.236654	valid_1's auc: 0.771477	valid_1's binary_logloss: 0.240488
# [400]	training's auc: 0.801442	training's binary_logloss: 0.233646	valid_1's auc: 0.774995	valid_1's binary_logloss: 0.239308
# [500]	training's auc: 0.808336	training's binary_logloss: 0.23111	valid_1's auc: 0.776863	valid_1's binary_logloss: 0.238667
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.808336	training's binary_logloss: 0.23111	valid_1's auc: 0.776863	valid_1's binary_logloss: 0.238667
# |  13       |  0.7769   |  0.7515   |  357.8    |  13.4     |  115.6    |  26.93    |  43.65    |  28.28    |  9.18     |  0.5243   |
# {'num_iterations': 500, 'learning_rate': 0.02, 'max_depth': 11, 'num_leaves': 56, 'min_child_samples': 167, 'min_child_weight': 31, 'subsample': 0.8740528651566337, 'colsample_bytree': 0.6037527720653292, 'max_bin': 434, 'reg_lambda': 1.6629701081009465, 'reg_alpha': 15.135504817281864}
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.774648	training's binary_logloss: 0.245754	valid_1's auc: 0.757596	valid_1's binary_logloss: 0.246618
# [200]	training's auc: 0.791799	training's binary_logloss: 0.237677	valid_1's auc: 0.767951	valid_1's binary_logloss: 0.241695
# [300]	training's auc: 0.804357	training's binary_logloss: 0.232805	valid_1's auc: 0.773456	valid_1's binary_logloss: 0.239751
# [400]	training's auc: 0.814871	training's binary_logloss: 0.228854	valid_1's auc: 0.776684	valid_1's binary_logloss: 0.238653
# [500]	training's auc: 0.824199	training's binary_logloss: 0.225374	valid_1's auc: 0.778359	valid_1's binary_logloss: 0.238073
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.824199	training's binary_logloss: 0.225374	valid_1's auc: 0.778359	valid_1's binary_logloss: 0.238073
# |  14       |  0.7784   |  0.6038   |  434.0    |  10.82    |  166.8    |  31.46    |  55.52    |  15.14    |  1.663    |  0.8741   |
# {'num_iterations': 500, 'learning_rate': 0.02, 'max_depth': 13, 'num_leaves': 56, 'min_child_samples': 195, 'min_child_weight': 8, 'subsample': 0.5195532251466721, 'colsample_bytree': 0.5489139254162854, 'max_bin': 433, 'reg_lambda': 0.736758583817566, 'reg_alpha': 21.770894233119083}
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.773754	training's binary_logloss: 0.246456	valid_1's auc: 0.75756	valid_1's binary_logloss: 0.247008
# [200]	training's auc: 0.789588	training's binary_logloss: 0.238628	valid_1's auc: 0.76725	valid_1's binary_logloss: 0.242058
# [300]	training's auc: 0.801029	training's binary_logloss: 0.234085	valid_1's auc: 0.772636	valid_1's binary_logloss: 0.240093
# [400]	training's auc: 0.810515	training's binary_logloss: 0.230519	valid_1's auc: 0.77564	valid_1's binary_logloss: 0.239056
# [500]	training's auc: 0.819338	training's binary_logloss: 0.227288	valid_1's auc: 0.777883	valid_1's binary_logloss: 0.238317
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.819338	training's binary_logloss: 0.227288	valid_1's auc: 0.777883	valid_1's binary_logloss: 0.238317
# |  15       |  0.7779   |  0.5489   |  432.8    |  13.11    |  195.5    |  8.062    |  56.04    |  21.77    |  0.7368   |  0.5196   |
# {'num_iterations': 500, 'learning_rate': 0.02, 'max_depth': 8, 'num_leaves': 63, 'min_child_samples': 164, 'min_child_weight': 27, 'subsample': 0.5399013145579242, 'colsample_bytree': 0.7447893372782468, 'max_bin': 410, 'reg_lambda': 1.8844994892501326, 'reg_alpha': 2.9900665414670877}
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.781326	training's binary_logloss: 0.2433	valid_1's auc: 0.759421	valid_1's binary_logloss: 0.24565
# [200]	training's auc: 0.801925	training's binary_logloss: 0.234123	valid_1's auc: 0.769413	valid_1's binary_logloss: 0.241039
# [300]	training's auc: 0.816372	training's binary_logloss: 0.228384	valid_1's auc: 0.774184	valid_1's binary_logloss: 0.239353
# [400]	training's auc: 0.827446	training's binary_logloss: 0.224152	valid_1's auc: 0.776321	valid_1's binary_logloss: 0.238667
# [500]	training's auc: 0.837494	training's binary_logloss: 0.220337	valid_1's auc: 0.777567	valid_1's binary_logloss: 0.238282
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.837494	training's binary_logloss: 0.220337	valid_1's auc: 0.777567	valid_1's binary_logloss: 0.238282
# |  16       |  0.7776   |  0.7448   |  410.4    |  8.187    |  163.9    |  26.9     |  63.42    |  2.99     |  1.884    |  0.5399   |
# {'num_iterations': 500, 'learning_rate': 0.02, 'max_depth': 13, 'num_leaves': 53, 'min_child_samples': 160, 'min_child_weight': 21, 'subsample': 0.9010369266915803, 'colsample_bytree': 0.8049127708123405, 'max_bin': 433, 'reg_lambda': 6.148289870077169, 'reg_alpha': 13.09037483603729}
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.773266	training's binary_logloss: 0.245712	valid_1's auc: 0.756749	valid_1's binary_logloss: 0.24649
# [200]	training's auc: 0.791918	training's binary_logloss: 0.237553	valid_1's auc: 0.767889	valid_1's binary_logloss: 0.241619
# [300]	training's auc: 0.804912	training's binary_logloss: 0.23252	valid_1's auc: 0.773811	valid_1's binary_logloss: 0.239591
# [400]	training's auc: 0.815794	training's binary_logloss: 0.22848	valid_1's auc: 0.776883	valid_1's binary_logloss: 0.23858
# [500]	training's auc: 0.825516	training's binary_logloss: 0.224898	valid_1's auc: 0.778411	valid_1's binary_logloss: 0.238077
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.825516	training's binary_logloss: 0.224898	valid_1's auc: 0.778411	valid_1's binary_logloss: 0.238077
# |  17       |  0.7784   |  0.8049   |  433.0    |  13.17    |  160.0    |  20.51    |  52.54    |  13.09    |  6.148    |  0.901    |
# {'num_iterations': 500, 'learning_rate': 0.02, 'max_depth': 9, 'num_leaves': 60, 'min_child_samples': 115, 'min_child_weight': 5, 'subsample': 0.6532037673285402, 'colsample_bytree': 0.7667250725713498, 'max_bin': 366, 'reg_lambda': 4.147001943170318, 'reg_alpha': 14.369994881475389}
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.774969	training's binary_logloss: 0.245186	valid_1's auc: 0.757009	valid_1's binary_logloss: 0.246452
# [200]	training's auc: 0.793812	training's binary_logloss: 0.236974	valid_1's auc: 0.768302	valid_1's binary_logloss: 0.241612
# [300]	training's auc: 0.806579	training's binary_logloss: 0.231951	valid_1's auc: 0.77383	valid_1's binary_logloss: 0.239658
# [400]	training's auc: 0.817411	training's binary_logloss: 0.22789	valid_1's auc: 0.776962	valid_1's binary_logloss: 0.238623
# [500]	training's auc: 0.82693	training's binary_logloss: 0.22429	valid_1's auc: 0.778626	valid_1's binary_logloss: 0.238036
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.82693	training's binary_logloss: 0.22429	valid_1's auc: 0.778626	valid_1's binary_logloss: 0.238036
# |  18       |  0.7786   |  0.7667   |  365.6    |  8.933    |  114.8    |  5.31     |  60.16    |  14.37    |  4.147    |  0.6532   |
# {'num_iterations': 500, 'learning_rate': 0.02, 'max_depth': 16, 'num_leaves': 46, 'min_child_samples': 159, 'min_child_weight': 22, 'subsample': 0.9750060472743405, 'colsample_bytree': 0.9064892234635891, 'max_bin': 435, 'reg_lambda': 8.49184767806519, 'reg_alpha': 4.001032818745956}
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.7723	training's binary_logloss: 0.245583	valid_1's auc: 0.756313	valid_1's binary_logloss: 0.246345
# [200]	training's auc: 0.792502	training's binary_logloss: 0.237203	valid_1's auc: 0.768761	valid_1's binary_logloss: 0.241284
# [300]	training's auc: 0.80668	training's binary_logloss: 0.231904	valid_1's auc: 0.774688	valid_1's binary_logloss: 0.23928
# [400]	training's auc: 0.818002	training's binary_logloss: 0.227686	valid_1's auc: 0.777121	valid_1's binary_logloss: 0.238424
# [500]	training's auc: 0.827863	training's binary_logloss: 0.224013	valid_1's auc: 0.778585	valid_1's binary_logloss: 0.237923
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.827863	training's binary_logloss: 0.224013	valid_1's auc: 0.778585	valid_1's binary_logloss: 0.237923
# |  19       |  0.7786   |  0.9065   |  435.3    |  15.95    |  159.0    |  21.59    |  46.18    |  4.001    |  8.492    |  0.975    |
# {'num_iterations': 500, 'learning_rate': 0.02, 'max_depth': 8, 'num_leaves': 58, 'min_child_samples': 106, 'min_child_weight': 9, 'subsample': 0.7352042374144658, 'colsample_bytree': 0.8631324203585278, 'max_bin': 387, 'reg_lambda': 8.397713347200538, 'reg_alpha': 23.489110863994107}
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.771367	training's binary_logloss: 0.24648	valid_1's auc: 0.755268	valid_1's binary_logloss: 0.24705
# [200]	training's auc: 0.788957	training's binary_logloss: 0.238752	valid_1's auc: 0.766724	valid_1's binary_logloss: 0.242117
# [300]	training's auc: 0.799914	training's binary_logloss: 0.234372	valid_1's auc: 0.772153	valid_1's binary_logloss: 0.240186
# [400]	training's auc: 0.80892	training's binary_logloss: 0.23098	valid_1's auc: 0.775267	valid_1's binary_logloss: 0.239136
# [500]	training's auc: 0.816882	training's binary_logloss: 0.227974	valid_1's auc: 0.777249	valid_1's binary_logloss: 0.238459
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.816882	training's binary_logloss: 0.227974	valid_1's auc: 0.777249	valid_1's binary_logloss: 0.238459
# |  20       |  0.7772   |  0.8631   |  387.0    |  7.754    |  106.4    |  9.013    |  58.1     |  23.49    |  8.398    |  0.7352   |
# {'num_iterations': 500, 'learning_rate': 0.02, 'max_depth': 14, 'num_leaves': 53, 'min_child_samples': 160, 'min_child_weight': 21, 'subsample': 0.9558339992559453, 'colsample_bytree': 0.9694572631554397, 'max_bin': 444, 'reg_lambda': 7.890145195250425, 'reg_alpha': 8.617013772077534}
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.773494	training's binary_logloss: 0.245219	valid_1's auc: 0.756412	valid_1's binary_logloss: 0.246308
# [200]	training's auc: 0.793817	training's binary_logloss: 0.236735	valid_1's auc: 0.768642	valid_1's binary_logloss: 0.241319
# [300]	training's auc: 0.808058	training's binary_logloss: 0.231346	valid_1's auc: 0.774109	valid_1's binary_logloss: 0.23949
# [400]	training's auc: 0.819902	training's binary_logloss: 0.226904	valid_1's auc: 0.777018	valid_1's binary_logloss: 0.238528
# [500]	training's auc: 0.83008	training's binary_logloss: 0.223049	valid_1's auc: 0.778668	valid_1's binary_logloss: 0.237985
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.83008	training's binary_logloss: 0.223049	valid_1's auc: 0.778668	valid_1's binary_logloss: 0.237985
# |  21       |  0.7787   |  0.9695   |  444.2    |  14.0     |  159.9    |  20.68    |  52.76    |  8.617    |  7.89     |  0.9558   |
# {'num_iterations': 500, 'learning_rate': 0.02, 'max_depth': 13, 'num_leaves': 56, 'min_child_samples': 167, 'min_child_weight': 23, 'subsample': 0.6700437819134917, 'colsample_bytree': 0.9422774565965977, 'max_bin': 433, 'reg_lambda': 4.266373836256442, 'reg_alpha': 5.25580377631261}
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.776321	training's binary_logloss: 0.244305	valid_1's auc: 0.756982	valid_1's binary_logloss: 0.246047
# [200]	training's auc: 0.797987	training's binary_logloss: 0.235297	valid_1's auc: 0.769149	valid_1's binary_logloss: 0.241107
# [300]	training's auc: 0.813651	training's binary_logloss: 0.229359	valid_1's auc: 0.775029	valid_1's binary_logloss: 0.239135
# [400]	training's auc: 0.826614	training's binary_logloss: 0.22448	valid_1's auc: 0.777437	valid_1's binary_logloss: 0.238321
# [500]	training's auc: 0.837811	training's binary_logloss: 0.220256	valid_1's auc: 0.778279	valid_1's binary_logloss: 0.238044
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.837811	training's binary_logloss: 0.220256	valid_1's auc: 0.778279	valid_1's binary_logloss: 0.238044
# |  22       |  0.7783   |  0.9423   |  432.9    |  13.31    |  166.8    |  23.29    |  55.58    |  5.256    |  4.266    |  0.67     |
# {'num_iterations': 500, 'learning_rate': 0.02, 'max_depth': 12, 'num_leaves': 62, 'min_child_samples': 108, 'min_child_weight': 9, 'subsample': 0.773731718803031, 'colsample_bytree': 0.6013787284477659, 'max_bin': 349, 'reg_lambda': 5.513581899056866, 'reg_alpha': 11.964113352102862}
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.776689	training's binary_logloss: 0.244952	valid_1's auc: 0.758042	valid_1's binary_logloss: 0.246369
# [200]	training's auc: 0.795598	training's binary_logloss: 0.236388	valid_1's auc: 0.768785	valid_1's binary_logloss: 0.241426
# [300]	training's auc: 0.80939	training's binary_logloss: 0.230996	valid_1's auc: 0.774216	valid_1's binary_logloss: 0.239459
# [400]	training's auc: 0.821202	training's binary_logloss: 0.226578	valid_1's auc: 0.777129	valid_1's binary_logloss: 0.238476
# [500]	training's auc: 0.831667	training's binary_logloss: 0.222605	valid_1's auc: 0.779045	valid_1's binary_logloss: 0.237868
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.831667	training's binary_logloss: 0.222605	valid_1's auc: 0.779045	valid_1's binary_logloss: 0.237868
# |  23       |  0.779    |  0.6014   |  348.8    |  12.1     |  107.8    |  8.843    |  61.56    |  11.96    |  5.514    |  0.7737   |
# {'num_iterations': 500, 'learning_rate': 0.02, 'max_depth': 14, 'num_leaves': 62, 'min_child_samples': 158, 'min_child_weight': 31, 'subsample': 0.5561168038945786, 'colsample_bytree': 0.6651565167402247, 'max_bin': 413, 'reg_lambda': 9.810863740395334, 'reg_alpha': 10.758076259199166}
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.776978	training's binary_logloss: 0.245021	valid_1's auc: 0.75801	valid_1's binary_logloss: 0.246368
# [200]	training's auc: 0.795822	training's binary_logloss: 0.236359	valid_1's auc: 0.768774	valid_1's binary_logloss: 0.241413
# [300]	training's auc: 0.809847	training's binary_logloss: 0.23091	valid_1's auc: 0.774333	valid_1's binary_logloss: 0.239461
# [400]	training's auc: 0.821792	training's binary_logloss: 0.226405	valid_1's auc: 0.777046	valid_1's binary_logloss: 0.238515
# [500]	training's auc: 0.832233	training's binary_logloss: 0.222423	valid_1's auc: 0.778451	valid_1's binary_logloss: 0.238012
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.832233	training's binary_logloss: 0.222423	valid_1's auc: 0.778451	valid_1's binary_logloss: 0.238012
# |  24       |  0.7785   |  0.6652   |  413.1    |  13.74    |  158.4    |  31.35    |  62.35    |  10.76    |  9.811    |  0.5561   |
# {'num_iterations': 500, 'learning_rate': 0.02, 'max_depth': 10, 'num_leaves': 63, 'min_child_samples': 105, 'min_child_weight': 16, 'subsample': 0.5109666846187021, 'colsample_bytree': 0.6817288558916161, 'max_bin': 364, 'reg_lambda': 9.226656044273998, 'reg_alpha': 0.019211789902964148}
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.781327	training's binary_logloss: 0.243263	valid_1's auc: 0.759397	valid_1's binary_logloss: 0.245662
# [200]	training's auc: 0.803272	training's binary_logloss: 0.233688	valid_1's auc: 0.770101	valid_1's binary_logloss: 0.240876
# [300]	training's auc: 0.819375	training's binary_logloss: 0.22738	valid_1's auc: 0.77516	valid_1's binary_logloss: 0.239119
# [400]	training's auc: 0.832313	training's binary_logloss: 0.222352	valid_1's auc: 0.777375	valid_1's binary_logloss: 0.238359
# [500]	training's auc: 0.8438	training's binary_logloss: 0.218027	valid_1's auc: 0.778489	valid_1's binary_logloss: 0.238
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.8438	training's binary_logloss: 0.218027	valid_1's auc: 0.778489	valid_1's binary_logloss: 0.238
# |  25       |  0.7785   |  0.6817   |  363.7    |  10.17    |  105.2    |  16.1     |  62.81    |  0.01921  |  9.227    |  0.511    |
# {'num_iterations': 500, 'learning_rate': 0.02, 'max_depth': 15, 'num_leaves': 54, 'min_child_samples': 79, 'min_child_weight': 10, 'subsample': 0.61520017446103, 'colsample_bytree': 0.6195573360163689, 'max_bin': 336, 'reg_lambda': 7.135785053838579, 'reg_alpha': 8.825410900743083}
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.774661	training's binary_logloss: 0.245384	valid_1's auc: 0.757709	valid_1's binary_logloss: 0.246343
# [200]	training's auc: 0.793713	training's binary_logloss: 0.237015	valid_1's auc: 0.768574	valid_1's binary_logloss: 0.241442
# [300]	training's auc: 0.807199	training's binary_logloss: 0.231772	valid_1's auc: 0.773943	valid_1's binary_logloss: 0.239532
# [400]	training's auc: 0.818709	training's binary_logloss: 0.227472	valid_1's auc: 0.776722	valid_1's binary_logloss: 0.238574
# [500]	training's auc: 0.82888	training's binary_logloss: 0.223687	valid_1's auc: 0.77837	valid_1's binary_logloss: 0.238038
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.82888	training's binary_logloss: 0.223687	valid_1's auc: 0.77837	valid_1's binary_logloss: 0.238038
# |  26       |  0.7784   |  0.6196   |  335.6    |  15.04    |  78.89    |  9.752    |  53.55    |  8.825    |  7.136    |  0.6152   |
# {'num_iterations': 500, 'learning_rate': 0.02, 'max_depth': 9, 'num_leaves': 64, 'min_child_samples': 92, 'min_child_weight': 2, 'subsample': 0.5010376712194866, 'colsample_bytree': 0.902650780737841, 'max_bin': 353, 'reg_lambda': 0.029200196110543707, 'reg_alpha': 13.562917108153172}
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.777133	training's binary_logloss: 0.244341	valid_1's auc: 0.757299	valid_1's binary_logloss: 0.24622
# [200]	training's auc: 0.796644	training's binary_logloss: 0.235793	valid_1's auc: 0.768439	valid_1's binary_logloss: 0.241431
# [300]	training's auc: 0.810411	training's binary_logloss: 0.23045	valid_1's auc: 0.774081	valid_1's binary_logloss: 0.239523
# [400]	training's auc: 0.82218	training's binary_logloss: 0.225968	valid_1's auc: 0.777051	valid_1's binary_logloss: 0.23852
# [500]	training's auc: 0.832743	training's binary_logloss: 0.221984	valid_1's auc: 0.778623	valid_1's binary_logloss: 0.238012
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.832743	training's binary_logloss: 0.221984	valid_1's auc: 0.778623	valid_1's binary_logloss: 0.238012
# |  27       |  0.7786   |  0.9027   |  353.3    |  9.461    |  92.37    |  2.363    |  63.56    |  13.56    |  0.0292   |  0.501    |
# {'num_iterations': 500, 'learning_rate': 0.02, 'max_depth': 10, 'num_leaves': 37, 'min_child_samples': 105, 'min_child_weight': 3, 'subsample': 0.710731824573511, 'colsample_bytree': 0.8140851110394289, 'max_bin': 354, 'reg_lambda': 1.5746302091763769, 'reg_alpha': 0.6769202713006536}
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.769615	training's binary_logloss: 0.246157	valid_1's auc: 0.755915	valid_1's binary_logloss: 0.246375
# [200]	training's auc: 0.789668	training's binary_logloss: 0.238105	valid_1's auc: 0.767991	valid_1's binary_logloss: 0.241478
# [300]	training's auc: 0.802864	training's binary_logloss: 0.233136	valid_1's auc: 0.773323	valid_1's binary_logloss: 0.239643
# [400]	training's auc: 0.813724	training's binary_logloss: 0.22918	valid_1's auc: 0.775933	valid_1's binary_logloss: 0.238784
# [500]	training's auc: 0.823327	training's binary_logloss: 0.225774	valid_1's auc: 0.777144	valid_1's binary_logloss: 0.238384
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.823327	training's binary_logloss: 0.225774	valid_1's auc: 0.777144	valid_1's binary_logloss: 0.238384
# |  28       |  0.7771   |  0.8141   |  354.1    |  10.49    |  104.8    |  2.596    |  37.32    |  0.6769   |  1.575    |  0.7107   |
# {'num_iterations': 500, 'learning_rate': 0.02, 'max_depth': 10, 'num_leaves': 46, 'min_child_samples': 136, 'min_child_weight': 46, 'subsample': 0.5792703435973909, 'colsample_bytree': 0.9414666730472483, 'max_bin': 446, 'reg_lambda': 9.816775877275758, 'reg_alpha': 10.826437849540993}
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.769854	training's binary_logloss: 0.246381	valid_1's auc: 0.755342	valid_1's binary_logloss: 0.24668
# [200]	training's auc: 0.788693	training's binary_logloss: 0.238528	valid_1's auc: 0.767641	valid_1's binary_logloss: 0.241712
# [300]	training's auc: 0.800892	training's binary_logloss: 0.233848	valid_1's auc: 0.77352	valid_1's binary_logloss: 0.239722
# [400]	training's auc: 0.810848	training's binary_logloss: 0.230154	valid_1's auc: 0.776404	valid_1's binary_logloss: 0.238752
# [500]	training's auc: 0.819488	training's binary_logloss: 0.226949	valid_1's auc: 0.778277	valid_1's binary_logloss: 0.238145
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.819488	training's binary_logloss: 0.226949	valid_1's auc: 0.778277	valid_1's binary_logloss: 0.238145
# |  29       |  0.7783   |  0.9415   |  445.6    |  10.49    |  135.9    |  45.6     |  45.56    |  10.83    |  9.817    |  0.5793   |
# {'num_iterations': 500, 'learning_rate': 0.02, 'max_depth': 6, 'num_leaves': 64, 'min_child_samples': 85, 'min_child_weight': 5, 'subsample': 1.0, 'colsample_bytree': 1.0, 'max_bin': 334, 'reg_lambda': 9.926332031778086, 'reg_alpha': 33.699294677420006}
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.763583	training's binary_logloss: 0.24868	valid_1's auc: 0.752109	valid_1's binary_logloss: 0.2479
# [200]	training's auc: 0.778912	training's binary_logloss: 0.242191	valid_1's auc: 0.763805	valid_1's binary_logloss: 0.243149
# [300]	training's auc: 0.787186	training's binary_logloss: 0.238826	valid_1's auc: 0.769445	valid_1's binary_logloss: 0.241128
# [400]	training's auc: 0.793026	training's binary_logloss: 0.236541	valid_1's auc: 0.772671	valid_1's binary_logloss: 0.240013
# [500]	training's auc: 0.798026	training's binary_logloss: 0.23467	valid_1's auc: 0.774839	valid_1's binary_logloss: 0.239287
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.798026	training's binary_logloss: 0.23467	valid_1's auc: 0.774839	valid_1's binary_logloss: 0.239287
# |  30       |  0.7748   |  1.0      |  333.6    |  6.0      |  85.41    |  5.163    |  64.0     |  33.7     |  9.926    |  1.0      |
# =====================================================================================================================================

# %%
lgbBO.res
# Out:
# [{'target': 0.7779410185743948,
#   'params': {'colsample_bytree': 0.7744067519636624,
#    'max_bin': 360.44278952248555,
#    'max_depth': 12.027633760716439,
#    'min_child_samples': 113.52780476941041,
#    'min_child_weight': 21.75908516760633,
#    'num_leaves': 49.835764522666246,
#    'reg_alpha': 21.884984691022,
#    'reg_lambda': 8.917838234820016,
#    'subsample': 0.9818313802505146}},
#  {'target': 0.7770706588920003,
#   'params': {'colsample_bytree': 0.6917207594128889,
#    'max_bin': 397.94526866050563,
#    'max_depth': 11.288949197529044,
#    'min_child_samples': 117.92846660784714,
#    'min_child_weight': 46.35423527634039,
#    'num_leaves': 26.841442327915477,
#    'reg_alpha': 4.36559369208002,
#    'reg_lambda': 0.20316375600581688,
#    'subsample': 0.916309922773969}},
#  {'target': 0.7784572757986459,
#   'params': {'colsample_bytree': 0.8890783754749252,
#    'max_bin': 436.30595264094137,
#    'max_depth': 15.78618342232764,
#    'min_child_samples': 161.8401272011775,
#    'min_child_weight': 23.61248875039366,
#    'num_leaves': 55.22116705145822,
#    'reg_alpha': 5.922538549187972,
#    'reg_lambda': 6.3995702922539115,
#    'subsample': 0.5716766437045232}},
#  {'target': 0.7765905850952646,
#   'params': {'colsample_bytree': 0.972334458524792,
#    'max_bin': 265.70567765753515,
#    'max_depth': 10.146619399905235,
#    'min_child_samples': 60.265566299879126,
#    'min_child_weight': 38.93745078227661,
#    'num_leaves': 42.24601328866194,
#    'reg_alpha': 28.426013103943742,
#    'reg_lambda': 0.18887921456311507,
#    'subsample': 0.8088177485379385}},
#  {'target': 0.776161186066826,
#   'params': {'colsample_bytree': 0.8060478613612108,
#    'max_bin': 312.2976584686309,
#    'max_depth': 15.437480785146242,
#    'min_child_samples': 139.54585682966186,
#    'min_child_weight': 18.615887128115514,
#    'num_leaves': 41.481278151973655,
#    'reg_alpha': 34.88458348440397,
#    'reg_lambda': 0.6031944908210691,
#    'subsample': 0.8333833577228338}},
#  {'target': 0.7786794720787867,
#   'params': {'colsample_bytree': 0.640481830861817,
#    'max_bin': 435.0379450370509,
#    'max_depth': 13.497244758196743,
#    'min_child_samples': 169.30259380663517,
#    'min_child_weight': 26.924368410534857,
#    'num_leaves': 57.69153705029583,
#    'reg_alpha': 5.7675960060342195,
#    'reg_lambda': 9.196441703351635,
#    'subsample': 0.6129607288812317}},
#  {'target': 0.7777650992807662,
#   'params': {'colsample_bytree': 0.7458994896937481,
#    'max_bin': 434.9349380046799,
#    'max_depth': 11.550340897666741,
#    'min_child_samples': 198.63371819857295,
#    'min_child_weight': 13.755300969795073,
#    'num_leaves': 53.106921148996264,
#    'reg_alpha': 24.607737391152277,
#    'reg_lambda': 8.539189077900696,
#    'subsample': 0.821334265834883}},
#  {'target': 0.777492578001182,
#   'params': {'colsample_bytree': 0.6784692502274292,
#    'max_bin': 455.6741792337822,
#    'max_depth': 8.43534728028535,
#    'min_child_samples': 182.04066936260696,
#    'min_child_weight': 49.44908327452929,
#    'num_leaves': 55.564121045548674,
#    'reg_alpha': 11.312397944233792,
#    'reg_lambda': 2.764765966445203,
#    'subsample': 0.8259963788588284}},
#  {'target': 0.7782009176907888,
#   'params': {'colsample_bytree': 0.6718633505505451,
#    'max_bin': 409.60336802768734,
#    'max_depth': 9.468913670616214,
#    'min_child_samples': 160.7939316369786,
#    'min_child_weight': 30.563711459098503,
#    'num_leaves': 63.19762422671231,
#    'reg_alpha': 9.031435769251694,
#    'reg_lambda': 8.332020869230849,
#    'subsample': 0.6222340399875712}},
#  {'target': 0.7771538493281773,
#   'params': {'colsample_bytree': 0.7672686131215163,
#    'max_bin': 416.49584824079113,
#    'max_depth': 13.98419318916709,
#    'min_child_samples': 176.42520346953083,
#    'min_child_weight': 17.7675559338572,
#    'num_leaves': 28.675737815025613,
#    'reg_alpha': 8.072671905016172,
#    'reg_lambda': 6.968999613934444,
#    'subsample': 0.9498668656246243}},
#  {'target': 0.7781304537066802,
#   'params': {'colsample_bytree': 0.6064052328429193,
#    'max_bin': 413.41645037382375,
#    'max_depth': 13.829507893606442,
#    'min_child_samples': 163.45045675684602,
#    'min_child_weight': 22.238910418614477,
#    'num_leaves': 63.866847324766276,
#    'reg_alpha': 14.185279785311755,
#    'reg_lambda': 8.472024590941542,
#    'subsample': 0.7226112226721547}},
#  {'target': 0.7775902517559199,
#   'params': {'colsample_bytree': 0.9715993400563504,
#    'max_bin': 467.78269182825323,
#    'max_depth': 8.133722266418522,
#    'min_child_samples': 165.66222529895842,
#    'min_child_weight': 10.045344355655551,
#    'num_leaves': 62.97140673645683,
#    'reg_alpha': 10.453510048238675,
#    'reg_lambda': 7.260412080797022,
#    'subsample': 0.8868793756279975}},
#  {'target': 0.7768626009748988,
#   'params': {'colsample_bytree': 0.7515227016933802,
#    'max_bin': 357.80423216845554,
#    'max_depth': 13.401381605474171,
#    'min_child_samples': 115.59284142483288,
#    'min_child_weight': 26.930427967219448,
#    'num_leaves': 43.65023202696482,
#    'reg_alpha': 28.27854101642585,
#    'reg_lambda': 9.179902256499673,
#    'subsample': 0.5242793368963636}},
#  {'target': 0.7783587998217655,
#   'params': {'colsample_bytree': 0.6037527720653292,
#    'max_bin': 433.98684699086493,
#    'max_depth': 10.818584298209332,
#    'min_child_samples': 166.83433731279288,
#    'min_child_weight': 31.460416079687867,
#    'num_leaves': 55.51554110704422,
#    'reg_alpha': 15.135504817281864,
#    'reg_lambda': 1.6629701081009465,
#    'subsample': 0.8740528651566337}},
#  {'target': 0.7778827836646265,
#   'params': {'colsample_bytree': 0.5489139254162854,
#    'max_bin': 432.7631122269628,
#    'max_depth': 13.114629350745906,
#    'min_child_samples': 195.463694550564,
#    'min_child_weight': 8.062158859997531,
#    'num_leaves': 56.0401774573515,
#    'reg_alpha': 21.770894233119083,
#    'reg_lambda': 0.736758583817566,
#    'subsample': 0.5195532251466721}},
#  {'target': 0.7775666102693805,
#   'params': {'colsample_bytree': 0.7447893372782468,
#    'max_bin': 410.44059558308476,
#    'max_depth': 8.18724002613589,
#    'min_child_samples': 163.94634680095297,
#    'min_child_weight': 26.90117418321104,
#    'num_leaves': 63.417831157496245,
#    'reg_alpha': 2.9900665414670877,
#    'reg_lambda': 1.8844994892501326,
#    'subsample': 0.5399013145579242}},
#  {'target': 0.7784106586699453,
#   'params': {'colsample_bytree': 0.8049127708123405,
#    'max_bin': 432.9794450102791,
#    'max_depth': 13.170789105561521,
#    'min_child_samples': 159.9998794806329,
#    'min_child_weight': 20.508130223447203,
#    'num_leaves': 52.54259117873046,
#    'reg_alpha': 13.09037483603729,
#    'reg_lambda': 6.148289870077169,
#    'subsample': 0.9010369266915803}},
#  {'target': 0.7786255065952609,
#   'params': {'colsample_bytree': 0.7667250725713498,
#    'max_bin': 365.6359940509268,
#    'max_depth': 8.932991061032517,
#    'min_child_samples': 114.75329319681849,
#    'min_child_weight': 5.309652577820957,
#    'num_leaves': 60.16400038513093,
#    'reg_alpha': 14.369994881475389,
#    'reg_lambda': 4.147001943170318,
#    'subsample': 0.6532037673285402}},
#  {'target': 0.7785845435282205,
#   'params': {'colsample_bytree': 0.9064892234635891,
#    'max_bin': 435.34892822359143,
#    'max_depth': 15.947286996295404,
#    'min_child_samples': 158.950483390625,
#    'min_child_weight': 21.59030619091277,
#    'num_leaves': 46.17841551310809,
#    'reg_alpha': 4.001032818745956,
#    'reg_lambda': 8.49184767806519,
#    'subsample': 0.9750060472743405}},
#  {'target': 0.7772490650742707,
#   'params': {'colsample_bytree': 0.8631324203585278,
#    'max_bin': 386.9711018550547,
#    'max_depth': 7.754313283964386,
#    'min_child_samples': 106.40080030096533,
#    'min_child_weight': 9.013305367463891,
#    'num_leaves': 58.09939281637965,
#    'reg_alpha': 23.489110863994107,
#    'reg_lambda': 8.397713347200538,
#    'subsample': 0.7352042374144658}},
#  {'target': 0.7786681286576917,
#   'params': {'colsample_bytree': 0.9694572631554397,
#    'max_bin': 444.2303414756819,
#    'max_depth': 14.000231745963585,
#    'min_child_samples': 159.91299562993436,
#    'min_child_weight': 20.681429069560544,
#    'num_leaves': 52.76009475818188,
#    'reg_alpha': 8.617013772077534,
#    'reg_lambda': 7.890145195250425,
#    'subsample': 0.9558339992559453}},
#  {'target': 0.7782786706652841,
#   'params': {'colsample_bytree': 0.9422774565965977,
#    'max_bin': 432.901127494436,
#    'max_depth': 13.31053943997927,
#    'min_child_samples': 166.77905663554327,
#    'min_child_weight': 23.28553184405287,
#    'num_leaves': 55.575924732862816,
#    'reg_alpha': 5.25580377631261,
#    'reg_lambda': 4.266373836256442,
#    'subsample': 0.6700437819134917}},
#  {'target': 0.7790445617713937,
#   'params': {'colsample_bytree': 0.6013787284477659,
#    'max_bin': 348.7945541058695,
#    'max_depth': 12.095550661878493,
#    'min_child_samples': 107.76369211353001,
#    'min_child_weight': 8.843095617583431,
#    'num_leaves': 61.56115763939606,
#    'reg_alpha': 11.964113352102862,
#    'reg_lambda': 5.513581899056866,
#    'subsample': 0.773731718803031}},
#  {'target': 0.7784509751459386,
#   'params': {'colsample_bytree': 0.6651565167402247,
#    'max_bin': 413.14018839489944,
#    'max_depth': 13.74165941998996,
#    'min_child_samples': 158.41951547910574,
#    'min_child_weight': 31.34982721216357,
#    'num_leaves': 62.35092505494774,
#    'reg_alpha': 10.758076259199166,
#    'reg_lambda': 9.810863740395334,
#    'subsample': 0.5561168038945786}},
#  {'target': 0.7784889459243873,
#   'params': {'colsample_bytree': 0.6817288558916161,
#    'max_bin': 363.6754959843349,
#    'max_depth': 10.166116169400894,
#    'min_child_samples': 105.16037004918752,
#    'min_child_weight': 16.099279514069014,
#    'num_leaves': 62.81017781379703,
#    'reg_alpha': 0.019211789902964148,
#    'reg_lambda': 9.226656044273998,
#    'subsample': 0.5109666846187021}},
#  {'target': 0.778369572060695,
#   'params': {'colsample_bytree': 0.6195573360163689,
#    'max_bin': 335.5900352178035,
#    'max_depth': 15.03823131850375,
#    'min_child_samples': 78.88820136605061,
#    'min_child_weight': 9.751953323697967,
#    'num_leaves': 53.545641655678494,
#    'reg_alpha': 8.825410900743083,
#    'reg_lambda': 7.135785053838579,
#    'subsample': 0.61520017446103}},
#  {'target': 0.7786230598177262,
#   'params': {'colsample_bytree': 0.902650780737841,
#    'max_bin': 353.2741785521837,
#    'max_depth': 9.460802890837181,
#    'min_child_samples': 92.36768667666087,
#    'min_child_weight': 2.363257090602527,
#    'num_leaves': 63.56392889850107,
#    'reg_alpha': 13.562917108153172,
#    'reg_lambda': 0.029200196110543707,
#    'subsample': 0.5010376712194866}},
#  {'target': 0.7771435327514249,
#   'params': {'colsample_bytree': 0.8140851110394289,
#    'max_bin': 354.05535064007677,
#    'max_depth': 10.494904681295163,
#    'min_child_samples': 104.80382518003385,
#    'min_child_weight': 2.5962752596190937,
#    'num_leaves': 37.31898546959056,
#    'reg_alpha': 0.6769202713006536,
#    'reg_lambda': 1.5746302091763769,
#    'subsample': 0.710731824573511}},
#  {'target': 0.7782767934654706,
#   'params': {'colsample_bytree': 0.9414666730472483,
#    'max_bin': 445.62703377256275,
#    'max_depth': 10.48605335628576,
#    'min_child_samples': 135.91879240697753,
#    'min_child_weight': 45.60420628223941,
#    'num_leaves': 45.56448717004104,
#    'reg_alpha': 10.826437849540993,
#    'reg_lambda': 9.816775877275758,
#    'subsample': 0.5792703435973909}},
#  {'target': 0.7748394994159502,
#   'params': {'colsample_bytree': 1.0,
#    'max_bin': 333.5891333270884,
#    'max_depth': 6.0,
#    'min_child_samples': 85.41277151606181,
#    'min_child_weight': 5.163441020244205,
#    'num_leaves': 64.0,
#    'reg_alpha': 33.699294677420006,
#    'reg_lambda': 9.926332031778086,
#    'subsample': 1.0}}]

# %%
target_list = []
for result in lgbBO.res:
    target = result['target']
    target_list.append(target)
print(target_list)
print(f'maximum target index: {np.argmax(np.array(target_list))}')
# Out:
# [0.7779410185743948, 0.7770706588920003, 0.7784572757986459, 0.7765905850952646, 0.776161186066826, 0.7786794720787867, 0.7777650992807662, 0.777492578001182, 0.7782009176907888, 0.7771538493281773, 0.7781304537066802, 0.7775902517559199, 0.7768626009748988, 0.7783587998217655, 0.7778827836646265, 0.7775666102693805, 0.7784106586699453, 0.7786255065952609, 0.7785845435282205, 0.7772490650742707, 0.7786681286576917, 0.7782786706652841, 0.7790445617713937, 0.7784509751459386, 0.7784889459243873, 0.778369572060695, 0.7786230598177262, 0.7771435327514249, 0.7782767934654706, 0.7748394994159502]
# maximum target index: 22

# %%
max_dict = lgbBO.res[np.argmax(np.array(target_list))]
print(max_dict)
# Out:
# {'target': 0.7790445617713937, 'params': {'colsample_bytree': 0.6013787284477659, 'max_bin': 348.7945541058695, 'max_depth': 12.095550661878493, 'min_child_samples': 107.76369211353001, 'min_child_weight': 8.843095617583431, 'num_leaves': 61.56115763939606, 'reg_alpha': 11.964113352102862, 'reg_lambda': 5.513581899056866, 'subsample': 0.773731718803031}}

# %%
def train_apps_all(apps_all_train):
    ftr_app = apps_all_train.drop(['SK_ID_CURR', 'TARGET'], axis=1)
    target_app = apps_all_train['TARGET']
    
    train_x, valid_x, train_y, valid_y = train_test_split(ftr_app, target_app, test_size=0.3, random_state=0)
    print(f'train_shape: {train_x.shape}, valid_shape: {valid_x.shape}')
    
    clf = LGBMClassifier(
        n_jobs=-1,
        n_estimators=1000, 
        learning_rate=0.02, 
        max_depth=round(max_dict['params']['max_depth']),
        num_leaves=round(max_dict['params']['num_leaves']),
        colsample_bytree=round(max_dict['params']['colsample_bytree'], 3),
        subsample=round(max_dict['params']['subsample'], 3),
        max_bin=round(max_dict['params']['max_bin']),
        reg_alpha=round(max_dict['params']['reg_alpha'], 3),
        reg_lambda=round(max_dict['params']['reg_lambda'], 3),
        min_child_weight=round(max_dict['params']['min_child_weight']),
        min_child_samples=round(max_dict['params']['min_child_samples']),
        silent=-1,
        verbose=-1,        
    )
    
    clf.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], 
            eval_metric='auc', verbose=100, early_stopping_rounds=100)
    
    return clf

# %%
apps_all = get_apps_all_with_prev_agg(apps, prev)
apps_all = get_apps_all_encoded(apps_all)
apps_all_train, apps_all_test = get_apps_all_train_test(apps_all)
clf = train_apps_all(apps_all_train)
# Out:
# prev_agg shape: (338857, 42)
# apps_all before merge shape: (356255, 136)
# apps_all after merge with prev_agg shape: (356255, 177)
# train_shape: (215257, 175), valid_shape: (92254, 175)
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.776689	training's binary_logloss: 0.244952	valid_1's auc: 0.758041	valid_1's binary_logloss: 0.246369
# [200]	training's auc: 0.795598	training's binary_logloss: 0.236388	valid_1's auc: 0.768785	valid_1's binary_logloss: 0.241426
# [300]	training's auc: 0.80939	training's binary_logloss: 0.230996	valid_1's auc: 0.774216	valid_1's binary_logloss: 0.239459
# [400]	training's auc: 0.821202	training's binary_logloss: 0.226578	valid_1's auc: 0.777129	valid_1's binary_logloss: 0.238476
# [500]	training's auc: 0.831667	training's binary_logloss: 0.222605	valid_1's auc: 0.779044	valid_1's binary_logloss: 0.237868
# [600]	training's auc: 0.84113	training's binary_logloss: 0.219	valid_1's auc: 0.780108	valid_1's binary_logloss: 0.237505
# [700]	training's auc: 0.849356	training's binary_logloss: 0.215741	valid_1's auc: 0.780738	valid_1's binary_logloss: 0.237314
# [800]	training's auc: 0.856918	training's binary_logloss: 0.212698	valid_1's auc: 0.781033	valid_1's binary_logloss: 0.237221
# [900]	training's auc: 0.863852	training's binary_logloss: 0.209801	valid_1's auc: 0.781108	valid_1's binary_logloss: 0.237196
# Early stopping, best iteration is:
# [874]	training's auc: 0.862081	training's binary_logloss: 0.210546	valid_1's auc: 0.781111	valid_1's binary_logloss: 0.237201

# %%
preds = clf.predict_proba(apps_all_test.drop('SK_ID_CURR', axis=1))[:, 1]
apps_all_test['TARGET'] = preds
apps_all_test[['SK_ID_CURR', 'TARGET']].to_csv('../result/hyper_parameter_tuning_result_01.csv', index=False)

# %%
bayesian_params = {
    'max_depth': (6, 16), 
    'num_leaves': (24, 64), 
    'min_data_in_leaf': (10, 200), # min_child_samples
    'min_child_weight': (1, 50),
    'bagging_fraction': (0.5, 1.0), # subsample
    'feature_fraction': (0.5, 1.0), # colsample_bytree
    'max_bin': (10, 500),
    'lambda_l2': (0.001, 10), # reg_lambda
    'lambda_l1': (0.01, 50), # reg_alpha
}

# %%
import lightgbm as lgb

train_data = lgb.Dataset(data=ftr_app, label=target_app, free_raw_data=False)

def lgb_roc_eval_cv(max_depth, num_leaves, min_data_in_leaf, min_child_weight, 
                    bagging_fraction, feature_fraction, max_bin, lambda_l2, lambda_l1):
    
    params = {
        'num_iterations': 500, 
        'learning_rate': 0.02,
        'early_stopping_rounds': 100,
        'metric': 'auc',
        'max_depth': int(round(max_depth)),
        'num_leaves': int(round(num_leaves)), 
        'min_data_in_leaf': int(round(min_data_in_leaf)),
        'min_child_weight': int(round(min_child_weight)),
        'bagging_fraction': max(min(bagging_fraction, 1), 0), 
        'feature_fraction': max(min(feature_fraction, 1), 0),
        'max_bin':  max(int(round(max_bin)), 10),
        'lambda_l2': max(lambda_l2, 0),
        'lambda_l1': max(lambda_l1, 0),
    }
    
    cv_result = lgb.cv(params, train_data, nfold=3, seed=0, verbose_eval=100, early_stopping_rounds=50, metrics=['auc'])
    
    return max(cv_result['auc-mean'])

# %%
lgbBO = BayesianOptimization(f=lgb_roc_eval_cv, pbounds=bayesian_params, random_state=0)
lgbBO.maximize(init_points=5, n_iter=25)
# Out:
# |   iter    |  target   | baggin... | featur... | lambda_l1 | lambda_l2 |  max_bin  | max_depth | min_ch... | min_da... | num_le... |
# -------------------------------------------------------------------------------------------------------------------------------------
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.143828 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 20434
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 165
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.121839 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 20434
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 165
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.123923 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 20434
# [LightGBM] [Info] Number of data points in the train set: 205008, number of used features: 165
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [100]	cv_agg's auc: 0.752245 + 0.00190698
# [200]	cv_agg's auc: 0.761822 + 0.00161546
# [300]	cv_agg's auc: 0.766654 + 0.00156361
# [400]	cv_agg's auc: 0.769264 + 0.00158445
# [500]	cv_agg's auc: 0.770725 + 0.00148508
# |  1        |  0.7707   |  0.7744   |  0.8576   |  30.14    |  5.449    |  217.6    |  12.46    |  22.44    |  179.4    |  62.55    |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.148926 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 40396
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 171
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.145146 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 40396
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 171
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.154478 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 40396
# [LightGBM] [Info] Number of data points in the train set: 205008, number of used features: 171
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [100]	cv_agg's auc: 0.75239 + 0.00232516
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [200]	cv_agg's auc: 0.762218 + 0.00223035
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [300]	cv_agg's auc: 0.766924 + 0.00210518
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [400]	cv_agg's auc: 0.769147 + 0.00194789
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [500]	cv_agg's auc: 0.770606 + 0.00173552
# |  2        |  0.7706   |  0.6917   |  0.8959   |  26.45    |  5.681    |  463.5    |  6.71     |  5.269    |  13.84    |  57.3     |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.124039 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21909
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 167
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.119901 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21909
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 167
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.147705 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21909
# [LightGBM] [Info] Number of data points in the train set: 205008, number of used features: 167
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [100]	cv_agg's auc: 0.747139 + 0.0024136
# [200]	cv_agg's auc: 0.757435 + 0.00232641
# [300]	cv_agg's auc: 0.762627 + 0.00214446
# [400]	cv_agg's auc: 0.765591 + 0.00220689
# [500]	cv_agg's auc: 0.767337 + 0.00211706
# |  3        |  0.7673   |  0.8891   |  0.935    |  48.93    |  7.992    |  236.1    |  13.81    |  6.795    |  131.6    |  29.73    |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.127574 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 34549
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 171
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.148947 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 34549
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 171
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.153008 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 34549
# [LightGBM] [Info] Number of data points in the train set: 205008, number of used features: 171
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [100]	cv_agg's auc: 0.751913 + 0.00223905
# [200]	cv_agg's auc: 0.762085 + 0.00221849
# [300]	cv_agg's auc: 0.767027 + 0.0022405
# [400]	cv_agg's auc: 0.769508 + 0.00218295
# [500]	cv_agg's auc: 0.770828 + 0.00192387
# |  4        |  0.7708   |  0.9723   |  0.7609   |  20.74    |  2.646    |  389.4    |  10.56    |  28.85    |  13.57    |  48.71    |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.124009 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17676
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 171
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.146265 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17676
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 171
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.145013 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17676
# [LightGBM] [Info] Number of data points in the train set: 205008, number of used features: 171
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [100]	cv_agg's auc: 0.750014 + 0.00224961
# [200]	cv_agg's auc: 0.759887 + 0.00203639
# [300]	cv_agg's auc: 0.76482 + 0.00198371
# [400]	cv_agg's auc: 0.767735 + 0.00199748
# [500]	cv_agg's auc: 0.76929 + 0.00196717
# |  5        |  0.7693   |  0.806    |  0.8085   |  47.19    |  6.819    |  186.2    |  10.37    |  35.18    |  21.44    |  50.67    |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.017505 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 20517
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 165
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.017768 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 20517
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 165
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.017877 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 20517
# [LightGBM] [Info] Number of data points in the train set: 205008, number of used features: 165
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [100]	cv_agg's auc: 0.754293 + 0.00207028
# [200]	cv_agg's auc: 0.762342 + 0.00186704
# [300]	cv_agg's auc: 0.766773 + 0.00195507
# [400]	cv_agg's auc: 0.769244 + 0.00193611
# [500]	cv_agg's auc: 0.770602 + 0.00180331
# |  6        |  0.7706   |  0.8999   |  0.5994   |  31.07    |  4.228    |  219.1    |  11.43    |  15.67    |  183.4    |  63.65    |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.120078 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 17664
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 165
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.026570 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 17664
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 165
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.020121 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 17664
# [LightGBM] [Info] Number of data points in the train set: 205008, number of used features: 165
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [100]	cv_agg's auc: 0.756272 + 0.00200983
# [200]	cv_agg's auc: 0.76429 + 0.00175676
# [300]	cv_agg's auc: 0.76847 + 0.00185334
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [400]	cv_agg's auc: 0.77089 + 0.00175743
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [500]	cv_agg's auc: 0.77226 + 0.00174036
# |  7        |  0.7723   |  0.7768   |  0.5736   |  9.075    |  6.668    |  186.3    |  7.69     |  48.64    |  199.9    |  60.46    |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.145000 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12005
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 165
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.144575 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12005
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 165
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.118669 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12005
# [LightGBM] [Info] Number of data points in the train set: 205008, number of used features: 165
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [100]	cv_agg's auc: 0.754237 + 0.00238011
# [200]	cv_agg's auc: 0.763758 + 0.0019542
# [300]	cv_agg's auc: 0.768067 + 0.00185763
# [400]	cv_agg's auc: 0.770214 + 0.00186719
# [500]	cv_agg's auc: 0.771372 + 0.00171085
# |  8        |  0.7714   |  0.5306   |  0.8141   |  11.26    |  4.491    |  121.0    |  15.52    |  46.64    |  194.6    |  59.22    |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.143048 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1503
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 165
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.124122 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1503
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 165
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.019316 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1503
# [LightGBM] [Info] Number of data points in the train set: 205008, number of used features: 165
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [100]	cv_agg's auc: 0.748676 + 0.0027742
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [200]	cv_agg's auc: 0.757285 + 0.00247074
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [300]	cv_agg's auc: 0.76194 + 0.00245845
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [400]	cv_agg's auc: 0.764316 + 0.00230253
# [500]	cv_agg's auc: 0.765722 + 0.0022277
# |  9        |  0.7657   |  0.9537   |  0.7495   |  42.33    |  9.804    |  10.74    |  7.883    |  11.55    |  198.5    |  40.75    |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.018292 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 40936
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 167
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.116801 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 40936
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 167
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.144736 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 40936
# [LightGBM] [Info] Number of data points in the train set: 205008, number of used features: 167
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [100]	cv_agg's auc: 0.753419 + 0.00239167
# [200]	cv_agg's auc: 0.763456 + 0.00226502
# [300]	cv_agg's auc: 0.768284 + 0.00199885
# [400]	cv_agg's auc: 0.770831 + 0.00195401
# [500]	cv_agg's auc: 0.772152 + 0.00195161
# |  10       |  0.7722   |  0.6444   |  0.5817   |  1.998    |  7.271    |  471.1    |  14.33    |  46.43    |  154.9    |  43.18    |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.152535 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 40936
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 167
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.140945 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 40936
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 167
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.152813 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 40936
# [LightGBM] [Info] Number of data points in the train set: 205008, number of used features: 167
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [100]	cv_agg's auc: 0.751269 + 0.0026493
# [200]	cv_agg's auc: 0.762964 + 0.00253685
# [300]	cv_agg's auc: 0.76803 + 0.00219627
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [400]	cv_agg's auc: 0.770619 + 0.0019399
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [500]	cv_agg's auc: 0.772134 + 0.00183119
# |  11       |  0.7721   |  0.7641   |  0.9781   |  7.537    |  6.76     |  470.9    |  7.874    |  46.02    |  153.5    |  40.77    |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.140097 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 34061
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 165
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.155998 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 34061
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 165
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.123051 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 34061
# [LightGBM] [Info] Number of data points in the train set: 205008, number of used features: 165
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [100]	cv_agg's auc: 0.755175 + 0.00235555
# [200]	cv_agg's auc: 0.76519 + 0.00205452
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [300]	cv_agg's auc: 0.769588 + 0.00191873
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [400]	cv_agg's auc: 0.771632 + 0.0018958
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [500]	cv_agg's auc: 0.772942 + 0.00198899
# |  12       |  0.7729   |  0.9184   |  0.8046   |  5.645    |  7.64     |  383.4    |  8.993    |  47.68    |  194.0    |  58.17    |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.126975 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12423
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 165
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.145670 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12423
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 165
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.145548 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12423
# [LightGBM] [Info] Number of data points in the train set: 205008, number of used features: 165
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [100]	cv_agg's auc: 0.754425 + 0.00233999
# [200]	cv_agg's auc: 0.763731 + 0.00190258
# [300]	cv_agg's auc: 0.768218 + 0.00166005
# [400]	cv_agg's auc: 0.770274 + 0.00181585
# [500]	cv_agg's auc: 0.771571 + 0.0017458
# |  13       |  0.7716   |  0.8208   |  0.7426   |  10.93    |  2.343    |  125.6    |  11.45    |  39.01    |  194.0    |  56.79    |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.121566 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 36614
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 165
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.121663 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 36614
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 165
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.150081 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 36614
# [LightGBM] [Info] Number of data points in the train set: 205008, number of used features: 165
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [100]	cv_agg's auc: 0.749842 + 0.00221706
# [200]	cv_agg's auc: 0.7591 + 0.00187342
# [300]	cv_agg's auc: 0.764237 + 0.00187438
# [400]	cv_agg's auc: 0.76722 + 0.0020233
# [500]	cv_agg's auc: 0.768926 + 0.00179557
# |  14       |  0.7689   |  0.9638   |  0.7418   |  48.62    |  8.588    |  415.3    |  9.927    |  3.727    |  199.3    |  36.56    |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.121214 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12088
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 165
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.122304 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12088
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 165
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.145612 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12088
# [LightGBM] [Info] Number of data points in the train set: 205008, number of used features: 165
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [100]	cv_agg's auc: 0.75451 + 0.00222696
# [200]	cv_agg's auc: 0.763469 + 0.00205285
# [300]	cv_agg's auc: 0.767929 + 0.00195273
# ...
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.126713 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 23840
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 165
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.123248 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 23840
# [LightGBM] [Info] Number of data points in the train set: 205008, number of used features: 165
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [100]	cv_agg's auc: 0.749954 + 0.0026475
# [200]	cv_agg's auc: 0.761592 + 0.0023654
# [300]	cv_agg's auc: 0.766551 + 0.00220619
# [400]	cv_agg's auc: 0.768814 + 0.00197228
# [500]	cv_agg's auc: 0.770122 + 0.00179337
# |  21       |  0.7701   |  0.6583   |  0.8274   |  1.637    |  8.205    |  258.3    |  14.39    |  45.8     |  193.6    |  30.12    |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.127693 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 39008
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 165
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.145837 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 39008
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 165
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.153318 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 39008
# [LightGBM] [Info] Number of data points in the train set: 205008, number of used features: 165
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [100]	cv_agg's auc: 0.753715 + 0.00243995
# [200]	cv_agg's auc: 0.764263 + 0.00222216
# [300]	cv_agg's auc: 0.768899 + 0.00209573
# [400]	cv_agg's auc: 0.770954 + 0.00214383
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [500]	cv_agg's auc: 0.772148 + 0.00204081
# |  22       |  0.7721   |  0.5626   |  0.7858   |  1.252    |  9.999    |  445.9    |  10.72    |  49.61    |  193.6    |  48.62    |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.118664 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 42774
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 165
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.019352 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 42774
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 165
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.117038 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 42774
# [LightGBM] [Info] Number of data points in the train set: 205008, number of used features: 165
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [100]	cv_agg's auc: 0.752268 + 0.00233717
# [200]	cv_agg's auc: 0.762613 + 0.00206768
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [300]	cv_agg's auc: 0.767714 + 0.00180925
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [400]	cv_agg's auc: 0.770441 + 0.0017251
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [500]	cv_agg's auc: 0.772098 + 0.00170697
# |  23       |  0.7721   |  0.8387   |  0.6137   |  2.03     |  8.781    |  495.0    |  7.616    |  40.23    |  199.8    |  34.46    |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.146480 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 42074
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 166
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.145459 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 42074
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 166
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.124453 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 42074
# [LightGBM] [Info] Number of data points in the train set: 205008, number of used features: 166
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [100]	cv_agg's auc: 0.754089 + 0.00256237
# [200]	cv_agg's auc: 0.765047 + 0.00231352
# [300]	cv_agg's auc: 0.769665 + 0.00198902
# [400]	cv_agg's auc: 0.771966 + 0.00204118
# [500]	cv_agg's auc: 0.773171 + 0.00217336
# |  24       |  0.7732   |  0.6202   |  0.7312   |  1.627    |  3.953    |  486.1    |  12.12    |  3.302    |  167.3    |  59.72    |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.120064 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 42621
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 167
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.124319 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 42621
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 167
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.146206 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 42621
# [LightGBM] [Info] Number of data points in the train set: 205008, number of used features: 167
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [100]	cv_agg's auc: 0.75193 + 0.00196705
# [200]	cv_agg's auc: 0.761752 + 0.00180133
# [300]	cv_agg's auc: 0.766649 + 0.0017854
# [400]	cv_agg's auc: 0.769146 + 0.00183961
# [500]	cv_agg's auc: 0.770811 + 0.00168568
# |  25       |  0.7708   |  0.8972   |  0.8229   |  36.95    |  7.707    |  493.0    |  10.54    |  4.385    |  140.0    |  61.07    |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.036938 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 42072
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 165
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.171637 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 42072
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 165
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.156615 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 42072
# [LightGBM] [Info] Number of data points in the train set: 205008, number of used features: 165
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [100]	cv_agg's auc: 0.753035 + 0.00265059
# [200]	cv_agg's auc: 0.764675 + 0.00220278
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [300]	cv_agg's auc: 0.76932 + 0.00183574
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [400]	cv_agg's auc: 0.771618 + 0.00196767
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [500]	cv_agg's auc: 0.772736 + 0.0020794
# |  26       |  0.7727   |  0.8555   |  0.9602   |  2.608    |  3.876    |  485.6    |  9.917    |  4.252    |  198.1    |  56.98    |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.147948 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 41694
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 167
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.126128 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 41694
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 167
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.126830 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 41694
# [LightGBM] [Info] Number of data points in the train set: 205008, number of used features: 167
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [100]	cv_agg's auc: 0.750113 + 0.00247744
# [200]	cv_agg's auc: 0.761504 + 0.00220231
# [300]	cv_agg's auc: 0.766774 + 0.00209104
# [400]	cv_agg's auc: 0.769635 + 0.00187473
# [500]	cv_agg's auc: 0.771299 + 0.0018438
# |  27       |  0.7713   |  0.9425   |  0.6197   |  2.495    |  1.449    |  480.6    |  8.087    |  3.911    |  156.2    |  28.23    |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.122028 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 42161
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 165
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.140005 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 42161
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 165
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.152321 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 42161
# [LightGBM] [Info] Number of data points in the train set: 205008, number of used features: 165
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [100]	cv_agg's auc: 0.753847 + 0.00190096
# [200]	cv_agg's auc: 0.76228 + 0.00172395
# [300]	cv_agg's auc: 0.76684 + 0.0017028
# [400]	cv_agg's auc: 0.769444 + 0.0017275
# [500]	cv_agg's auc: 0.771058 + 0.00169688
# |  28       |  0.7711   |  0.6095   |  0.6572   |  32.29    |  8.918    |  486.5    |  14.51    |  38.11    |  183.7    |  63.75    |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.163078 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 14135
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 167
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.143719 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 14135
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 167
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.145031 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 14135
# [LightGBM] [Info] Number of data points in the train set: 205008, number of used features: 167
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [100]	cv_agg's auc: 0.7512 + 0.00260318
# [200]	cv_agg's auc: 0.762493 + 0.00229856
# [300]	cv_agg's auc: 0.767021 + 0.00217777
# [400]	cv_agg's auc: 0.76916 + 0.00217435
# [500]	cv_agg's auc: 0.770392 + 0.00206235
# |  29       |  0.7704   |  0.7266   |  0.7515   |  0.8875   |  7.214    |  146.3    |  8.818    |  46.78    |  137.7    |  37.17    |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.127100 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 36125
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 165
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.146792 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 36125
# [LightGBM] [Info] Number of data points in the train set: 205007, number of used features: 165
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.125528 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 36125
# [LightGBM] [Info] Number of data points in the train set: 205008, number of used features: 165
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [LightGBM] [Info] Start training from score 0.080729
# [100]	cv_agg's auc: 0.756173 + 0.00203921
# [200]	cv_agg's auc: 0.765266 + 0.00197748
# [300]	cv_agg's auc: 0.769608 + 0.0020799
# [400]	cv_agg's auc: 0.771703 + 0.0018686
# [500]	cv_agg's auc: 0.772893 + 0.00198201
# |  30       |  0.7729   |  0.8253   |  0.6241   |  3.941    |  0.06979  |  409.2    |  15.13    |  47.86    |  199.0    |  62.37    |
# =====================================================================================================================================

# %%
max_dict = lgbBO.res[np.argmax(np.array(target_list))]
print(max_dict)
# Out:
# {'target': 0.7720982152503876, 'params': {'bagging_fraction': 0.8386515465125856, 'feature_fraction': 0.6137100057774653, 'lambda_l1': 2.029918642228829, 'lambda_l2': 8.780977921949715, 'max_bin': 495.033560028543, 'max_depth': 7.61623668276145, 'min_child_weight': 40.232413573410355, 'min_data_in_leaf': 199.82554538351746, 'num_leaves': 34.460922099466856}}

# %%
def train_apps_all(apps_all_train):
    ftr_app = apps_all_train.drop(['SK_ID_CURR', 'TARGET'], axis=1)
    target_app = apps_all_train['TARGET']
    
    train_x, valid_x, train_y, valid_y = train_test_split(ftr_app, target_app, test_size=0.3, random_state=0)
    print(f'train_shape: {train_x.shape}, valid_shape: {valid_x.shape}')
    
    clf = LGBMClassifier(
        n_jobs=-1,
        n_estimators=1000, 
        learning_rate=0.02, 
        max_depth=round(max_dict['params']['max_depth']),
        num_leaves=round(max_dict['params']['num_leaves']),
        colsample_bytree=round(max_dict['params']['feature_fraction'], 3),
        subsample=round(max_dict['params']['bagging_fraction'], 3),
        max_bin=round(max_dict['params']['max_bin']),
        reg_alpha=round(max_dict['params']['lambda_l1'], 3),
        reg_lambda=round(max_dict['params']['lambda_l2'], 3),
        min_child_weight=round(max_dict['params']['min_child_weight']),
        min_child_samples=round(max_dict['params']['min_data_in_leaf']),
        silent=-1,
        verbose=-1,        
    )
    
    clf.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], 
            eval_metric='auc', verbose=100, early_stopping_rounds=100)
    
    return clf

# %%
apps_all = get_apps_all_with_prev_agg(apps, prev)
apps_all = get_apps_all_encoded(apps_all)
apps_all_train, apps_all_test = get_apps_all_train_test(apps_all)
clf = train_apps_all(apps_all_train)
# Out:
# prev_agg shape: (338857, 42)
# apps_all before merge shape: (356255, 136)
# apps_all after merge with prev_agg shape: (356255, 177)
# train_shape: (215257, 175), valid_shape: (92254, 175)
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.767574	training's binary_logloss: 0.247444	valid_1's auc: 0.755815	valid_1's binary_logloss: 0.246967
# [200]	training's auc: 0.784581	training's binary_logloss: 0.239994	valid_1's auc: 0.766951	valid_1's binary_logloss: 0.241976
# [300]	training's auc: 0.795286	training's binary_logloss: 0.235804	valid_1's auc: 0.77226	valid_1's binary_logloss: 0.24004
# [400]	training's auc: 0.803836	training's binary_logloss: 0.232632	valid_1's auc: 0.775254	valid_1's binary_logloss: 0.239031
# [500]	training's auc: 0.811465	training's binary_logloss: 0.2299	valid_1's auc: 0.776926	valid_1's binary_logloss: 0.238474
# [600]	training's auc: 0.817912	training's binary_logloss: 0.227553	valid_1's auc: 0.777989	valid_1's binary_logloss: 0.238136
# [700]	training's auc: 0.823978	training's binary_logloss: 0.225346	valid_1's auc: 0.778614	valid_1's binary_logloss: 0.237946
# [800]	training's auc: 0.829585	training's binary_logloss: 0.223278	valid_1's auc: 0.779126	valid_1's binary_logloss: 0.237777
# [900]	training's auc: 0.835171	training's binary_logloss: 0.221208	valid_1's auc: 0.779536	valid_1's binary_logloss: 0.237641
# [1000]	training's auc: 0.84017	training's binary_logloss: 0.219302	valid_1's auc: 0.779906	valid_1's binary_logloss: 0.237545
# Did not meet early stopping. Best iteration is:
# [1000]	training's auc: 0.84017	training's binary_logloss: 0.219302	valid_1's auc: 0.779906	valid_1's binary_logloss: 0.237545

# %%
preds = clf.predict_proba(apps_all_test.drop('SK_ID_CURR', axis=1))[:, 1]
apps_all_test['TARGET'] = preds
apps_all_test[['SK_ID_CURR', 'TARGET']].to_csv('../result/hyper_parameter_tuning_result_02.csv', index=False)
