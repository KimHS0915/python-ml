# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from bayes_opt import BayesianOptimization
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
from lightgbm import LGBMClassifier

# %%
def get_apps_dataset():
    app_train = pd.read_csv('../data/home-credit-default-risk/application_train.csv')
    app_test = pd.read_csv('../data/home-credit-default-risk/application_test.csv')
    apps = pd.concat([app_train, app_test])
    prev = pd.read_csv('../data/home-credit-default-risk/previous_application.csv')
    
    return apps, prev


def get_apps_processed(apps):
    apps['APPS_EXT_SOURCE_MEAN'] = apps[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']].mean(axis=1)
    apps['APPS_EXT_SOURCE_STD'] = apps[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']].std(axis=1)
    apps['APPS_EXT_SOURCE_STD'] = apps['APPS_EXT_SOURCE_STD'].fillna(apps['APPS_EXT_SOURCE_STD'].mean())
    
    apps['APPS_ANNUITY_CREDIT_RATIO'] = apps['AMT_ANNUITY'] / apps['AMT_CREDIT']
    apps['APPS_GOODS_CREDIT_RATIO'] = apps['AMT_GOODS_PRICE'] / apps['AMT_CREDIT']
    apps['APPS_CREDIT_GOODS_DIFF'] = apps['AMT_CREDIT'] - apps['AMT_GOODS_PRICE']
    
    apps['APPS_ANNUITY_INCOME_RATIO'] = apps['AMT_ANNUITY'] / apps['AMT_INCOME_TOTAL']
    apps['APPS_CREDIT_INCOME_RATIO'] = apps['AMT_CREDIT'] / apps['AMT_INCOME_TOTAL']
    apps['APPS_GOODS_INCOME_RATIO'] = apps['AMT_GOODS_PRICE'] / apps['AMT_INCOME_TOTAL']
    apps['APPS_CNT_FAM_INCOME_RATIO'] = apps['AMT_INCOME_TOTAL'] / apps['CNT_FAM_MEMBERS']
    
    apps['APPS_EMPLOYED_BIRTH_RATIO'] = apps['DAYS_EMPLOYED'] / apps['DAYS_BIRTH']
    apps['APPS_INCOME_EMPLOYED_RATIO'] = apps['AMT_INCOME_TOTAL'] / apps['DAYS_EMPLOYED']
    apps['APPS_INCOME_BIRTH_RATIO'] = apps['AMT_INCOME_TOTAL'] / apps['DAYS_BIRTH']
    apps['APPS_CAR_BIRTH_RATIO'] = apps['OWN_CAR_AGE'] / apps['DAYS_BIRTH']
    apps['APPS_CAR_EMPLOYED_RATIO'] = apps['OWN_CAR_AGE'] / apps['DAYS_EMPLOYED']
    
    return apps

# %%
def get_prev_processed(prev):
    
    prev['PREV_CREDIT_DIFF'] = prev['AMT_APPLICATION'] - prev['AMT_CREDIT']
    prev['PREV_GOODS_DIFF'] = prev['AMT_APPLICATION'] - prev['AMT_GOODS_PRICE']
    prev['PREV_CREDIT_APPL_RATIO'] = prev['AMT_CREDIT'] / prev['AMT_APPLICATION']
    prev['PREV_ANNUITY_APPL_RATIO'] = prev['AMT_ANNUITY'] / prev['AMT_APPLICATION']
    prev['PREV_GOODS_APPL_RATIO'] = prev['AMT_GOODS_PRICE'] / prev['AMT_APPLICATION']
    
    prev['DAYS_FIRST_DRAWING'].replace(365243, np.nan, inplace=True)
    prev['DAYS_FIRST_DUE'].replace(365243, np.nan, inplace=True)
    prev['DAYS_LAST_DUE_1ST_VERSION'].replace(365243, np.nan, inplace=True)
    prev['DAYS_LAST_DUE'].replace(365243, np.nan, inplace=True)
    prev['DAYS_TERMINATION'].replace(365243, np.nan, inplace=True)

    prev['PREV_DAYS_LAST_DUE_DIFF'] = prev['DAYS_LAST_DUE_1ST_VERSION'] - prev['DAYS_LAST_DUE']
    
    all_pay = prev['AMT_ANNUITY'] * prev['CNT_PAYMENT']
    prev['PREV_INTERESTS_RATE'] = (all_pay / prev['AMT_CREDIT'] - 1) / prev['CNT_PAYMENT']
    
    return prev


def get_prev_amt_agg(prev):    

    agg_dict = {
         # 기존 컬럼. 
        'SK_ID_CURR':['count'],
        'AMT_CREDIT':['mean', 'max', 'sum'],
        'AMT_ANNUITY':['mean', 'max', 'sum'], 
        'AMT_APPLICATION':['mean', 'max', 'sum'],
        'AMT_DOWN_PAYMENT':['mean', 'max', 'sum'],
        'AMT_GOODS_PRICE':['mean', 'max', 'sum'],
        'RATE_DOWN_PAYMENT': ['min', 'max', 'mean'],
        'DAYS_DECISION': ['min', 'max', 'mean'],
        'CNT_PAYMENT': ['mean', 'sum'],
        # 가공 컬럼
        'PREV_CREDIT_DIFF':['mean', 'max', 'sum'], 
        'PREV_CREDIT_APPL_RATIO':['mean', 'max'],
        'PREV_GOODS_DIFF':['mean', 'max', 'sum'],
        'PREV_GOODS_APPL_RATIO':['mean', 'max'],
        'PREV_DAYS_LAST_DUE_DIFF':['mean', 'max', 'sum'],
        'PREV_INTERESTS_RATE':['mean', 'max']
    }
    
    prev_group = prev.groupby('SK_ID_CURR')
    prev_amt_agg = prev_group.agg(agg_dict)
    prev_amt_agg.columns = ['PREV_' + ('_').join(column).upper() for column in prev_amt_agg.columns.ravel()]
    prev_amt_agg = prev_amt_agg.reset_index()
    
    return prev_amt_agg


def get_prev_refused_appr_agg(prev):

    prev_refused_appr_group = prev[prev['NAME_CONTRACT_STATUS'].isin(['Approved', 'Refused'])].groupby(['SK_ID_CURR', 'NAME_CONTRACT_STATUS'])
    prev_refused_appr_agg = prev_refused_appr_group['SK_ID_CURR'].count().unstack()
    prev_refused_appr_agg = prev_refused_appr_agg.fillna(0)
    prev_refused_appr_agg.columns = ['PREV_APPROVED_COUNT', 'PREV_REFUSED_COUNT']
    prev_refused_appr_agg = prev_refused_appr_agg.reset_index()
    
    return prev_refused_appr_agg


def get_prev_agg(prev):
    
    prev = get_prev_processed(prev)
    prev_amt_agg = get_prev_amt_agg(prev)
    prev_refused_appr_agg = get_prev_refused_appr_agg(prev)
    
    prev_agg = prev_amt_agg.merge(prev_refused_appr_agg, on='SK_ID_CURR', how='left')
    prev_agg['PREV_REFUSED_RATIO'] = prev_agg['PREV_REFUSED_COUNT'] / prev_agg['PREV_SK_ID_CURR_COUNT']
    prev_agg['PREV_APPROVED_RATIO'] = prev_agg['PREV_APPROVED_COUNT'] / prev_agg['PREV_SK_ID_CURR_COUNT']
    prev_agg = prev_agg.drop(['PREV_REFUSED_COUNT', 'PREV_APPROVED_COUNT'], axis=1)
    
    return prev_agg


def get_apps_all_with_prev_agg(apps, prev):

    apps_all = get_apps_processed(apps)
    prev_agg = get_prev_agg(prev)
    print('prev_agg shape:', prev_agg.shape)
    print('apps_all before merge shape:', apps_all.shape)
    apps_all = apps_all.merge(prev_agg, on='SK_ID_CURR', how='left')
    print('apps_all after merge with prev_agg shape:', apps_all.shape)
    
    return apps_all


def get_apps_all_encoded(apps_all):
    
    object_columns = apps_all.dtypes[apps_all.dtypes == 'object'].index.tolist()
    for column in object_columns:
        apps_all[column] = pd.factorize(apps_all[column])[0]
    
    return apps_all


def get_apps_all_train_test(apps_all):

    apps_all_train = apps_all[~apps_all['TARGET'].isnull()]
    apps_all_test = apps_all[apps_all['TARGET'].isnull()]
    apps_all_test = apps_all_test.drop('TARGET', axis=1)
    
    return apps_all_train, apps_all_test


def train_apps_all(apps_all_train):
    
    ftr_app = apps_all_train.drop(['SK_ID_CURR', 'TARGET'], axis=1)
    target_app = apps_all_train['TARGET']

    train_x, valid_x, train_y, valid_y = train_test_split(ftr_app, target_app, test_size=0.3, random_state=0)
    print(f'train shape: {train_x.shape}, valid shape: {valid_x.shape}')
    
    clf = LGBMClassifier(n_jobs=-1, n_estimators=1000, learning_rate=0.02, num_leaves=32, 
                         subsample=0.8, max_depth=12, silent=-1, verbose=-1)
    clf.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], 
            eval_metric='auc', verbose=100, early_stopping_rounds=100)
    
    return clf

# %%
apps, prev = get_apps_dataset()
apps_all = get_apps_all_with_prev_agg(apps, prev)
apps_all = get_apps_all_encoded(apps_all)
apps_all_train, apps_all_test = get_apps_all_train_test(apps_all)
print(f'apps_all_train.shape: {apps_all_train.shape}, apps_all_test.shape: {apps_all_test.shape}')
# Out:
# prev_agg shape: (338857, 42)
# apps_all before merge shape: (356255, 136)
# apps_all after merge with prev_agg shape: (356255, 177)
# apps_all_train.shape: (307511, 177), apps_all_test.shape: (48744, 176)

# %%
ftr_app = apps_all_train.drop(['SK_ID_CURR', 'TARGET'], axis=1)
target_app = apps_all_train['TARGET']
train_x, valid_x, train_y, valid_y = train_test_split(ftr_app, target_app, test_size=0.3, random_state=2020)

# %%
bayesian_params = {
    'max_depth': (6, 16),
    'num_leaves': (24, 64),
    'min_child_samples': (10, 200),
    'min_child_weight': (1, 50),
    'subsample': (0.5, 1),
    'colsample_bytree': (0.5, 1),
    'max_bin': (10, 500),
    'reg_lambda': (0.001, 10),
    'reg_alpha': (0.01, 50),
}

# %%
def lgb_roc_eval(max_depth, num_leaves, min_child_samples, min_child_weight, subsample,
                colsample_bytree, max_bin, reg_lambda, reg_alpha):
    
    params = {
        "num_iterations": 500, 
        "learning_rate": 0.02,
        'max_depth': int(round(max_depth)),
        'num_leaves': int(round(num_leaves)),
        'min_child_samples': int(round(min_child_samples)),
        'min_child_weight': int(round(min_child_weight)),
        'subsample': max(min(subsample, 1), 0),
        'colsample_bytree': max(min(colsample_bytree, 1), 0),
        'max_bin': max(int(round(max_bin)),10),
        'reg_lambda': max(reg_lambda,0),
        'reg_alpha': max(reg_alpha, 0),
    }
    
    lgb_model = LGBMClassifier(**params)
    lgb_model.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], eval_metric= 'auc', verbose= 100, 
                early_stopping_rounds= 100)
    valid_proba = lgb_model.predict_proba(valid_x)[:, 1]
    roc_auc = roc_auc_score(valid_y, valid_proba)
    
    return roc_auc

# %%
lgbBO = BayesianOptimization(f=lgb_roc_eval, pbounds=bayesian_params, random_state=0)
lgbBO.maximize(init_points=5, n_iter=25)
# Out:
# |   iter    |  target   | colsam... |  max_bin  | max_depth | min_ch... | min_ch... | num_le... | reg_alpha | reg_la... | subsample |
# -------------------------------------------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.769845	training's binary_logloss: 0.245974	valid_1's auc: 0.75468	valid_1's binary_logloss: 0.249084
# [200]	training's auc: 0.787445	training's binary_logloss: 0.238391	valid_1's auc: 0.765781	valid_1's binary_logloss: 0.244325
# [300]	training's auc: 0.799122	training's binary_logloss: 0.233874	valid_1's auc: 0.77075	valid_1's binary_logloss: 0.242501
# [400]	training's auc: 0.808061	training's binary_logloss: 0.23054	valid_1's auc: 0.773265	valid_1's binary_logloss: 0.241605
# [500]	training's auc: 0.816162	training's binary_logloss: 0.227564	valid_1's auc: 0.774917	valid_1's binary_logloss: 0.241044
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.816162	training's binary_logloss: 0.227564	valid_1's auc: 0.774917	valid_1's binary_logloss: 0.241044
# |  1        |  0.7749   |  0.7744   |  360.4    |  12.03    |  113.5    |  21.76    |  49.84    |  21.88    |  8.918    |  0.9818   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.762806	training's binary_logloss: 0.247403	valid_1's auc: 0.753685	valid_1's binary_logloss: 0.249131
# [200]	training's auc: 0.780157	training's binary_logloss: 0.240455	valid_1's auc: 0.765659	valid_1's binary_logloss: 0.244264
# [300]	training's auc: 0.7909	training's binary_logloss: 0.23647	valid_1's auc: 0.770845	valid_1's binary_logloss: 0.242378
# [400]	training's auc: 0.79916	training's binary_logloss: 0.233474	valid_1's auc: 0.773878	valid_1's binary_logloss: 0.241316
# [500]	training's auc: 0.806149	training's binary_logloss: 0.23101	valid_1's auc: 0.775519	valid_1's binary_logloss: 0.240768
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.806149	training's binary_logloss: 0.23101	valid_1's auc: 0.775519	valid_1's binary_logloss: 0.240768
# |  2        |  0.7755   |  0.6917   |  397.9    |  11.29    |  117.9    |  46.35    |  26.84    |  4.366    |  0.2032   |  0.9163   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.776202	training's binary_logloss: 0.243773	valid_1's auc: 0.75729	valid_1's binary_logloss: 0.247932
# [200]	training's auc: 0.797263	training's binary_logloss: 0.234922	valid_1's auc: 0.768796	valid_1's binary_logloss: 0.24316
# [300]	training's auc: 0.812283	training's binary_logloss: 0.229194	valid_1's auc: 0.773266	valid_1's binary_logloss: 0.241561
# [400]	training's auc: 0.825067	training's binary_logloss: 0.224388	valid_1's auc: 0.775788	valid_1's binary_logloss: 0.240665
# [500]	training's auc: 0.835712	training's binary_logloss: 0.220358	valid_1's auc: 0.776889	valid_1's binary_logloss: 0.240225
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.835712	training's binary_logloss: 0.220358	valid_1's auc: 0.776889	valid_1's binary_logloss: 0.240225
# |  3        |  0.7769   |  0.8891   |  436.3    |  15.79    |  161.8    |  23.61    |  55.22    |  5.923    |  6.4      |  0.5717   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.765963	training's binary_logloss: 0.246838	valid_1's auc: 0.753413	valid_1's binary_logloss: 0.249283
# [200]	training's auc: 0.783152	training's binary_logloss: 0.239731	valid_1's auc: 0.765068	valid_1's binary_logloss: 0.244555
# [300]	training's auc: 0.793631	training's binary_logloss: 0.235742	valid_1's auc: 0.770288	valid_1's binary_logloss: 0.242677
# [400]	training's auc: 0.80158	training's binary_logloss: 0.232776	valid_1's auc: 0.773138	valid_1's binary_logloss: 0.24166
# [500]	training's auc: 0.808251	training's binary_logloss: 0.230309	valid_1's auc: 0.774765	valid_1's binary_logloss: 0.241083
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.808251	training's binary_logloss: 0.230309	valid_1's auc: 0.774765	valid_1's binary_logloss: 0.241083
# |  4        |  0.7748   |  0.9723   |  265.7    |  10.15    |  60.27    |  38.94    |  42.25    |  28.43    |  0.1889   |  0.8088   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.76582	training's binary_logloss: 0.247277	valid_1's auc: 0.753528	valid_1's binary_logloss: 0.249657
# [200]	training's auc: 0.781699	training's binary_logloss: 0.240333	valid_1's auc: 0.764126	valid_1's binary_logloss: 0.244954
# [300]	training's auc: 0.791732	training's binary_logloss: 0.236501	valid_1's auc: 0.769384	valid_1's binary_logloss: 0.243053
# [400]	training's auc: 0.79926	training's binary_logloss: 0.233706	valid_1's auc: 0.772102	valid_1's binary_logloss: 0.24211
# [500]	training's auc: 0.805839	training's binary_logloss: 0.231354	valid_1's auc: 0.774018	valid_1's binary_logloss: 0.241452
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.805839	training's binary_logloss: 0.231354	valid_1's auc: 0.774018	valid_1's binary_logloss: 0.241452
# |  5        |  0.774    |  0.806    |  312.3    |  15.44    |  139.5    |  18.62    |  41.48    |  34.88    |  0.6032   |  0.8334   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.778168	training's binary_logloss: 0.243254	valid_1's auc: 0.75725	valid_1's binary_logloss: 0.248015
# [200]	training's auc: 0.799041	training's binary_logloss: 0.234369	valid_1's auc: 0.768351	valid_1's binary_logloss: 0.24336
# [300]	training's auc: 0.813984	training's binary_logloss: 0.228603	valid_1's auc: 0.773038	valid_1's binary_logloss: 0.241706
# [400]	training's auc: 0.826987	training's binary_logloss: 0.223711	valid_1's auc: 0.775909	valid_1's binary_logloss: 0.240674
# [500]	training's auc: 0.838295	training's binary_logloss: 0.219424	valid_1's auc: 0.777087	valid_1's binary_logloss: 0.240249
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.838295	training's binary_logloss: 0.219424	valid_1's auc: 0.777087	valid_1's binary_logloss: 0.240249
# |  6        |  0.7771   |  0.9075   |  492.9    |  15.69    |  181.9    |  15.53    |  63.68    |  12.48    |  1.06     |  0.9755   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.775462	training's binary_logloss: 0.244432	valid_1's auc: 0.758886	valid_1's binary_logloss: 0.247979
# [200]	training's auc: 0.794769	training's binary_logloss: 0.235914	valid_1's auc: 0.769091	valid_1's binary_logloss: 0.243129
# [300]	training's auc: 0.808583	training's binary_logloss: 0.230596	valid_1's auc: 0.773395	valid_1's binary_logloss: 0.241481
# [400]	training's auc: 0.820146	training's binary_logloss: 0.226246	valid_1's auc: 0.775937	valid_1's binary_logloss: 0.240572
# [500]	training's auc: 0.830462	training's binary_logloss: 0.222441	valid_1's auc: 0.777541	valid_1's binary_logloss: 0.240033
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.830462	training's binary_logloss: 0.222441	valid_1's auc: 0.777541	valid_1's binary_logloss: 0.240033
# |  7        |  0.7775   |  0.6269   |  437.7    |  10.07    |  156.5    |  22.14    |  48.87    |  2.432    |  7.948    |  0.8027   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.762767	training's binary_logloss: 0.247367	valid_1's auc: 0.753828	valid_1's binary_logloss: 0.249033
# [200]	training's auc: 0.780741	training's binary_logloss: 0.240269	valid_1's auc: 0.765729	valid_1's binary_logloss: 0.244184
# [300]	training's auc: 0.792035	training's binary_logloss: 0.2361	valid_1's auc: 0.771235	valid_1's binary_logloss: 0.242231
# [400]	training's auc: 0.800508	training's binary_logloss: 0.233064	valid_1's auc: 0.773895	valid_1's binary_logloss: 0.241296
# [500]	training's auc: 0.80759	training's binary_logloss: 0.23056	valid_1's auc: 0.775387	valid_1's binary_logloss: 0.240783
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.80759	training's binary_logloss: 0.23056	valid_1's auc: 0.775387	valid_1's binary_logloss: 0.240783
# |  8        |  0.7754   |  0.8218   |  467.8    |  6.64     |  154.6    |  9.083    |  25.52    |  0.1423   |  1.165    |  0.8718   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.775625	training's binary_logloss: 0.244194	valid_1's auc: 0.757539	valid_1's binary_logloss: 0.248146
# [200]	training's auc: 0.795457	training's binary_logloss: 0.235638	valid_1's auc: 0.768221	valid_1's binary_logloss: 0.243418
# [300]	training's auc: 0.809659	training's binary_logloss: 0.230193	valid_1's auc: 0.773137	valid_1's binary_logloss: 0.241662
# [400]	training's auc: 0.821157	training's binary_logloss: 0.225818	valid_1's auc: 0.775756	valid_1's binary_logloss: 0.24071
# [500]	training's auc: 0.8314	training's binary_logloss: 0.221974	valid_1's auc: 0.77712	valid_1's binary_logloss: 0.240227
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.8314	training's binary_logloss: 0.221974	valid_1's auc: 0.77712	valid_1's binary_logloss: 0.240227
# |  9        |  0.7771   |  0.8063   |  436.4    |  11.21    |  142.5    |  8.396    |  53.53    |  7.698    |  8.194    |  0.5522   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.77619	training's binary_logloss: 0.244009	valid_1's auc: 0.75806	valid_1's binary_logloss: 0.247998
# [200]	training's auc: 0.796467	training's binary_logloss: 0.235275	valid_1's auc: 0.768807	valid_1's binary_logloss: 0.243218
# [300]	training's auc: 0.810218	training's binary_logloss: 0.229861	valid_1's auc: 0.773019	valid_1's binary_logloss: 0.241631
# [400]	training's auc: 0.821875	training's binary_logloss: 0.225471	valid_1's auc: 0.775381	valid_1's binary_logloss: 0.240814
# [500]	training's auc: 0.83201	training's binary_logloss: 0.221631	valid_1's auc: 0.776726	valid_1's binary_logloss: 0.240338
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.83201	training's binary_logloss: 0.221631	valid_1's auc: 0.776726	valid_1's binary_logloss: 0.240338
# |  10       |  0.7767   |  0.7987   |  434.4    |  9.933    |  138.4    |  34.69    |  53.85    |  4.798    |  8.556    |  0.8878   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.777244	training's binary_logloss: 0.243888	valid_1's auc: 0.758355	valid_1's binary_logloss: 0.248055
# [200]	training's auc: 0.79643	training's binary_logloss: 0.235378	valid_1's auc: 0.768477	valid_1's binary_logloss: 0.243343
# [300]	training's auc: 0.810062	training's binary_logloss: 0.230019	valid_1's auc: 0.772892	valid_1's binary_logloss: 0.2417
# [400]	training's auc: 0.821347	training's binary_logloss: 0.225731	valid_1's auc: 0.775102	valid_1's binary_logloss: 0.24092
# [500]	training's auc: 0.831448	training's binary_logloss: 0.221898	valid_1's auc: 0.776602	valid_1's binary_logloss: 0.240383
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.831448	training's binary_logloss: 0.221898	valid_1's auc: 0.776602	valid_1's binary_logloss: 0.240383
# |  11       |  0.7766   |  0.6897   |  437.1    |  9.322    |  139.8    |  7.79     |  56.61    |  9.517    |  1.885    |  0.7773   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.766935	training's binary_logloss: 0.246144	valid_1's auc: 0.7545	valid_1's binary_logloss: 0.248668
# [200]	training's auc: 0.786059	training's binary_logloss: 0.238552	valid_1's auc: 0.76663	valid_1's binary_logloss: 0.243897
# [300]	training's auc: 0.798482	training's binary_logloss: 0.233926	valid_1's auc: 0.772126	valid_1's binary_logloss: 0.241976
# [400]	training's auc: 0.808389	training's binary_logloss: 0.230314	valid_1's auc: 0.775085	valid_1's binary_logloss: 0.240939
# [500]	training's auc: 0.816567	training's binary_logloss: 0.227354	valid_1's auc: 0.776335	valid_1's binary_logloss: 0.240478
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.816567	training's binary_logloss: 0.227354	valid_1's auc: 0.776335	valid_1's binary_logloss: 0.240478
# |  12       |  0.7763   |  0.9394   |  415.0    |  11.58    |  157.3    |  9.417    |  35.68    |  6.317    |  4.801    |  0.9134   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.777799	training's binary_logloss: 0.243373	valid_1's auc: 0.758369	valid_1's binary_logloss: 0.247799
# [200]	training's auc: 0.798411	training's binary_logloss: 0.234484	valid_1's auc: 0.768941	valid_1's binary_logloss: 0.243107
# [300]	training's auc: 0.81323	training's binary_logloss: 0.228753	valid_1's auc: 0.773071	valid_1's binary_logloss: 0.241593
# [400]	training's auc: 0.826038	training's binary_logloss: 0.223923	valid_1's auc: 0.775485	valid_1's binary_logloss: 0.240724
# [500]	training's auc: 0.837131	training's binary_logloss: 0.219724	valid_1's auc: 0.776644	valid_1's binary_logloss: 0.240308
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.837131	training's binary_logloss: 0.219724	valid_1's auc: 0.776644	valid_1's binary_logloss: 0.240308
# |  13       |  0.7766   |  0.7828   |  436.1    |  12.16    |  142.0    |  35.04    |  56.53    |  6.646    |  1.154    |  0.5147   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.765562	training's binary_logloss: 0.247763	valid_1's auc: 0.753768	valid_1's binary_logloss: 0.249756
# [200]	training's auc: 0.780092	training's binary_logloss: 0.241171	valid_1's auc: 0.763928	valid_1's binary_logloss: 0.245055
# [300]	training's auc: 0.788871	training's binary_logloss: 0.237647	valid_1's auc: 0.769057	valid_1's binary_logloss: 0.243097
# [400]	training's auc: 0.794893	training's binary_logloss: 0.235293	valid_1's auc: 0.771805	valid_1's binary_logloss: 0.242085
# [500]	training's auc: 0.800009	training's binary_logloss: 0.233351	valid_1's auc: 0.773527	valid_1's binary_logloss: 0.241452
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.800009	training's binary_logloss: 0.233351	valid_1's auc: 0.773527	valid_1's binary_logloss: 0.241452
# |  14       |  0.7735   |  0.7581   |  489.9    |  6.158    |  197.4    |  45.37    |  61.67    |  27.72    |  9.923    |  0.874    |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.777208	training's binary_logloss: 0.243934	valid_1's auc: 0.759806	valid_1's binary_logloss: 0.247724
# [200]	training's auc: 0.79667	training's binary_logloss: 0.235207	valid_1's auc: 0.769498	valid_1's binary_logloss: 0.242929
# [300]	training's auc: 0.811378	training's binary_logloss: 0.22955	valid_1's auc: 0.773744	valid_1's binary_logloss: 0.241308
# [400]	training's auc: 0.823828	training's binary_logloss: 0.224881	valid_1's auc: 0.776283	valid_1's binary_logloss: 0.24042
# [500]	training's auc: 0.834491	training's binary_logloss: 0.220858	valid_1's auc: 0.777429	valid_1's binary_logloss: 0.240003
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.834491	training's binary_logloss: 0.220858	valid_1's auc: 0.777429	valid_1's binary_logloss: 0.240003
# |  15       |  0.7774   |  0.6034   |  426.2    |  13.55    |  143.7    |  34.64    |  51.92    |  2.171    |  6.253    |  0.6305   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.777479	training's binary_logloss: 0.243292	valid_1's auc: 0.757271	valid_1's binary_logloss: 0.247927
# [200]	training's auc: 0.798701	training's binary_logloss: 0.234336	valid_1's auc: 0.768787	valid_1's binary_logloss: 0.243196
# [300]	training's auc: 0.813829	training's binary_logloss: 0.228525	valid_1's auc: 0.773394	valid_1's binary_logloss: 0.241566
# [400]	training's auc: 0.826715	training's binary_logloss: 0.223707	valid_1's auc: 0.775769	valid_1's binary_logloss: 0.240717
# [500]	training's auc: 0.83796	training's binary_logloss: 0.219416	valid_1's auc: 0.777134	valid_1's binary_logloss: 0.240227
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.83796	training's binary_logloss: 0.219416	valid_1's auc: 0.777134	valid_1's binary_logloss: 0.240227
# |  16       |  0.7771   |  0.9248   |  443.7    |  12.65    |  138.7    |  12.81    |  59.84    |  9.45     |  1.863    |  0.7829   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.77554	training's binary_logloss: 0.24414	valid_1's auc: 0.758001	valid_1's binary_logloss: 0.248017
# [200]	training's auc: 0.795368	training's binary_logloss: 0.235589	valid_1's auc: 0.768438	valid_1's binary_logloss: 0.243268
# [300]	training's auc: 0.809847	training's binary_logloss: 0.230092	valid_1's auc: 0.773334	valid_1's binary_logloss: 0.241515
# [400]	training's auc: 0.821905	training's binary_logloss: 0.225525	valid_1's auc: 0.776223	valid_1's binary_logloss: 0.240514
# [500]	training's auc: 0.832399	training's binary_logloss: 0.221638	valid_1's auc: 0.777575	valid_1's binary_logloss: 0.240022
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.832399	training's binary_logloss: 0.221638	valid_1's auc: 0.777575	valid_1's binary_logloss: 0.240022
# |  17       |  0.7776   |  0.681    |  437.7    |  11.99    |  143.3    |  13.72    |  50.63    |  6.026    |  2.739    |  0.7539   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.764321	training's binary_logloss: 0.246949	valid_1's auc: 0.754471	valid_1's binary_logloss: 0.248956
# [200]	training's auc: 0.78242	training's binary_logloss: 0.239656	valid_1's auc: 0.766346	valid_1's binary_logloss: 0.244017
# [300]	training's auc: 0.793905	training's binary_logloss: 0.235409	valid_1's auc: 0.771624	valid_1's binary_logloss: 0.242094
# [400]	training's auc: 0.802663	training's binary_logloss: 0.232255	valid_1's auc: 0.774335	valid_1's binary_logloss: 0.241143
# [500]	training's auc: 0.809994	training's binary_logloss: 0.229639	valid_1's auc: 0.775698	valid_1's binary_logloss: 0.240656
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.809994	training's binary_logloss: 0.229639	valid_1's auc: 0.775698	valid_1's binary_logloss: 0.240656
# |  18       |  0.7757   |  0.7492   |  419.0    |  15.3     |  158.4    |  46.05    |  28.05    |  0.6349   |  0.3607   |  0.9667   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.775077	training's binary_logloss: 0.243774	valid_1's auc: 0.757212	valid_1's binary_logloss: 0.247749
# [200]	training's auc: 0.79711	training's binary_logloss: 0.23479	valid_1's auc: 0.769237	valid_1's binary_logloss: 0.242937
# [300]	training's auc: 0.812169	training's binary_logloss: 0.229037	valid_1's auc: 0.77352	valid_1's binary_logloss: 0.241378
# [400]	training's auc: 0.824725	training's binary_logloss: 0.224345	valid_1's auc: 0.77618	valid_1's binary_logloss: 0.240475
# [500]	training's auc: 0.835008	training's binary_logloss: 0.220447	valid_1's auc: 0.777218	valid_1's binary_logloss: 0.24011
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.835008	training's binary_logloss: 0.220447	valid_1's auc: 0.777218	valid_1's binary_logloss: 0.24011
# |  19       |  0.7772   |  0.9743   |  440.1    |  10.74    |  158.4    |  25.92    |  50.89    |  0.3118   |  8.606    |  0.5562   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.777549	training's binary_logloss: 0.243676	valid_1's auc: 0.758606	valid_1's binary_logloss: 0.247973
# [200]	training's auc: 0.797466	training's binary_logloss: 0.234937	valid_1's auc: 0.76864	valid_1's binary_logloss: 0.24329
# [300]	training's auc: 0.812104	training's binary_logloss: 0.229314	valid_1's auc: 0.773036	valid_1's binary_logloss: 0.241649
# [400]	training's auc: 0.824497	training's binary_logloss: 0.224621	valid_1's auc: 0.775653	valid_1's binary_logloss: 0.240731
# [500]	training's auc: 0.835652	training's binary_logloss: 0.220443	valid_1's auc: 0.777334	valid_1's binary_logloss: 0.240133
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.835652	training's binary_logloss: 0.220443	valid_1's auc: 0.777334	valid_1's binary_logloss: 0.240133
# |  20       |  0.7773   |  0.6101   |  478.8    |  12.76    |  128.8    |  17.63    |  60.23    |  9.403    |  1.822    |  0.7143   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.778525	training's binary_logloss: 0.243157	valid_1's auc: 0.758562	valid_1's binary_logloss: 0.247701
# [200]	training's auc: 0.800787	training's binary_logloss: 0.233784	valid_1's auc: 0.769629	valid_1's binary_logloss: 0.242888
# [300]	training's auc: 0.816779	training's binary_logloss: 0.227605	valid_1's auc: 0.774019	valid_1's binary_logloss: 0.241272
# [400]	training's auc: 0.830156	training's binary_logloss: 0.222537	valid_1's auc: 0.776485	valid_1's binary_logloss: 0.24042
# [500]	training's auc: 0.841573	training's binary_logloss: 0.218233	valid_1's auc: 0.77761	valid_1's binary_logloss: 0.240022
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.841573	training's binary_logloss: 0.218233	valid_1's auc: 0.77761	valid_1's binary_logloss: 0.240022
# |  21       |  0.7776   |  0.8047   |  499.5    |  15.33    |  144.2    |  8.629    |  56.57    |  2.508    |  7.647    |  0.7904   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.770672	training's binary_logloss: 0.246556	valid_1's auc: 0.755032	valid_1's binary_logloss: 0.249558
# [200]	training's auc: 0.786583	training's binary_logloss: 0.239113	valid_1's auc: 0.764954	valid_1's binary_logloss: 0.244782
# [300]	training's auc: 0.797455	training's binary_logloss: 0.23483	valid_1's auc: 0.769796	valid_1's binary_logloss: 0.242939
# [400]	training's auc: 0.805852	training's binary_logloss: 0.23161	valid_1's auc: 0.772687	valid_1's binary_logloss: 0.241927
# [500]	training's auc: 0.813352	training's binary_logloss: 0.228842	valid_1's auc: 0.77444	valid_1's binary_logloss: 0.241307
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.813352	training's binary_logloss: 0.228842	valid_1's auc: 0.77444	valid_1's binary_logloss: 0.241307
# |  22       |  0.7744   |  0.5962   |  499.3    |  11.53    |  129.8    |  19.02    |  60.56    |  38.92    |  8.39     |  0.6936   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.779234	training's binary_logloss: 0.242703	valid_1's auc: 0.758104	valid_1's binary_logloss: 0.247536
# [200]	training's auc: 0.802302	training's binary_logloss: 0.233172	valid_1's auc: 0.769478	valid_1's binary_logloss: 0.242868
# [300]	training's auc: 0.81837	training's binary_logloss: 0.226891	valid_1's auc: 0.773601	valid_1's binary_logloss: 0.24134
# [400]	training's auc: 0.831809	training's binary_logloss: 0.221821	valid_1's auc: 0.775485	valid_1's binary_logloss: 0.240659
# [500]	training's auc: 0.843647	training's binary_logloss: 0.217356	valid_1's auc: 0.776886	valid_1's binary_logloss: 0.240197
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.843647	training's binary_logloss: 0.217356	valid_1's auc: 0.776886	valid_1's binary_logloss: 0.240197
# |  23       |  0.7769   |  0.9488   |  461.3    |  9.533    |  153.4    |  5.146    |  61.04    |  2.258    |  7.513    |  0.5478   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.782968	training's binary_logloss: 0.242296	valid_1's auc: 0.760337	valid_1's binary_logloss: 0.247565
# [200]	training's auc: 0.805183	training's binary_logloss: 0.232482	valid_1's auc: 0.769653	valid_1's binary_logloss: 0.242905
# [300]	training's auc: 0.822727	training's binary_logloss: 0.225679	valid_1's auc: 0.774074	valid_1's binary_logloss: 0.24124
# [400]	training's auc: 0.838031	training's binary_logloss: 0.219981	valid_1's auc: 0.776445	valid_1's binary_logloss: 0.240432
# [500]	training's auc: 0.850585	training's binary_logloss: 0.215176	valid_1's auc: 0.777489	valid_1's binary_logloss: 0.240075
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.850585	training's binary_logloss: 0.215176	valid_1's auc: 0.777489	valid_1's binary_logloss: 0.240075
# |  24       |  0.7775   |  0.5485   |  470.6    |  15.11    |  99.16    |  1.328    |  62.54    |  1.55     |  3.798    |  0.6965   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.782903	training's binary_logloss: 0.242218	valid_1's auc: 0.760557	valid_1's binary_logloss: 0.24749
# [200]	training's auc: 0.806393	training's binary_logloss: 0.232354	valid_1's auc: 0.770177	valid_1's binary_logloss: 0.242812
# [300]	training's auc: 0.82335	training's binary_logloss: 0.22574	valid_1's auc: 0.774397	valid_1's binary_logloss: 0.241184
# [400]	training's auc: 0.837016	training's binary_logloss: 0.220548	valid_1's auc: 0.776602	valid_1's binary_logloss: 0.24041
# [500]	training's auc: 0.848675	training's binary_logloss: 0.216214	valid_1's auc: 0.777493	valid_1's binary_logloss: 0.240086
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.848675	training's binary_logloss: 0.216214	valid_1's auc: 0.777493	valid_1's binary_logloss: 0.240086
# |  25       |  0.7775   |  0.5192   |  490.6    |  8.061    |  123.3    |  3.779    |  60.4     |  0.2817   |  0.1735   |  0.5395   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.781295	training's binary_logloss: 0.24242	valid_1's auc: 0.759424	valid_1's binary_logloss: 0.247468
# [200]	training's auc: 0.803222	training's binary_logloss: 0.233063	valid_1's auc: 0.76931	valid_1's binary_logloss: 0.242971
# [300]	training's auc: 0.818052	training's binary_logloss: 0.227168	valid_1's auc: 0.773385	valid_1's binary_logloss: 0.241434
# [400]	training's auc: 0.829373	training's binary_logloss: 0.222793	valid_1's auc: 0.775528	valid_1's binary_logloss: 0.240693
# [500]	training's auc: 0.839169	training's binary_logloss: 0.219033	valid_1's auc: 0.776875	valid_1's binary_logloss: 0.240229
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.839169	training's binary_logloss: 0.219033	valid_1's auc: 0.776875	valid_1's binary_logloss: 0.240229
# |  26       |  0.7769   |  0.6778   |  482.3    |  7.862    |  80.13    |  24.24    |  61.17    |  0.4256   |  2.99     |  0.7567   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.764438	training's binary_logloss: 0.247669	valid_1's auc: 0.75503	valid_1's binary_logloss: 0.249397
# [200]	training's auc: 0.780588	training's binary_logloss: 0.240549	valid_1's auc: 0.766209	valid_1's binary_logloss: 0.244296
# [300]	training's auc: 0.791466	training's binary_logloss: 0.236442	valid_1's auc: 0.771599	valid_1's binary_logloss: 0.242255
# [400]	training's auc: 0.799766	training's binary_logloss: 0.233416	valid_1's auc: 0.774331	valid_1's binary_logloss: 0.24126
# [500]	training's auc: 0.806933	training's binary_logloss: 0.230911	valid_1's auc: 0.776026	valid_1's binary_logloss: 0.240666
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.806933	training's binary_logloss: 0.230911	valid_1's auc: 0.776026	valid_1's binary_logloss: 0.240666
# |  27       |  0.776    |  0.5397   |  464.1    |  13.88    |  87.11    |  2.805    |  27.02    |  0.8345   |  8.625    |  0.6967   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.774396	training's binary_logloss: 0.244398	valid_1's auc: 0.755916	valid_1's binary_logloss: 0.248569
# [200]	training's auc: 0.793827	training's binary_logloss: 0.236152	valid_1's auc: 0.767214	valid_1's binary_logloss: 0.243849
# [300]	training's auc: 0.806698	training's binary_logloss: 0.23113	valid_1's auc: 0.77227	valid_1's binary_logloss: 0.242071
# [400]	training's auc: 0.817204	training's binary_logloss: 0.227169	valid_1's auc: 0.77463	valid_1's binary_logloss: 0.241231
# [500]	training's auc: 0.826645	training's binary_logloss: 0.223603	valid_1's auc: 0.776101	valid_1's binary_logloss: 0.240708
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.826645	training's binary_logloss: 0.223603	valid_1's auc: 0.776101	valid_1's binary_logloss: 0.240708
# |  28       |  0.7761   |  0.9182   |  489.7    |  10.03    |  52.45    |  1.513    |  63.05    |  21.39    |  1.938    |  0.5829   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.776128	training's binary_logloss: 0.243868	valid_1's auc: 0.757955	valid_1's binary_logloss: 0.247892
# [200]	training's auc: 0.796816	training's binary_logloss: 0.235113	valid_1's auc: 0.768665	valid_1's binary_logloss: 0.243198
# [300]	training's auc: 0.811749	training's binary_logloss: 0.229435	valid_1's auc: 0.773193	valid_1's binary_logloss: 0.241576
# [400]	training's auc: 0.824062	training's binary_logloss: 0.224811	valid_1's auc: 0.77572	valid_1's binary_logloss: 0.240688
# [500]	training's auc: 0.834668	training's binary_logloss: 0.220888	valid_1's auc: 0.776937	valid_1's binary_logloss: 0.240269
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.834668	training's binary_logloss: 0.220888	valid_1's auc: 0.776937	valid_1's binary_logloss: 0.240269
# |  29       |  0.7769   |  0.7036   |  464.0    |  9.953    |  118.0    |  10.16    |  50.54    |  0.7542   |  8.533    |  0.5139   |
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.782125	training's binary_logloss: 0.242387	valid_1's auc: 0.759125	valid_1's binary_logloss: 0.247569
# [200]	training's auc: 0.804611	training's binary_logloss: 0.233057	valid_1's auc: 0.769043	valid_1's binary_logloss: 0.243122
# [300]	training's auc: 0.819601	training's binary_logloss: 0.227136	valid_1's auc: 0.773119	valid_1's binary_logloss: 0.241554
# [400]	training's auc: 0.831002	training's binary_logloss: 0.222598	valid_1's auc: 0.775295	valid_1's binary_logloss: 0.240751
# [500]	training's auc: 0.840828	training's binary_logloss: 0.218885	valid_1's auc: 0.776453	valid_1's binary_logloss: 0.24036
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.840828	training's binary_logloss: 0.218885	valid_1's auc: 0.776453	valid_1's binary_logloss: 0.24036
# |  30       |  0.7765   |  0.7553   |  498.8    |  7.287    |  93.14    |  3.903    |  62.87    |  0.7519   |  2.936    |  0.5491   |
# =====================================================================================================================================
